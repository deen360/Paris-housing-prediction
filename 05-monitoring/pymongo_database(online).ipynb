# %%
#we import the pymongo library
import pymongo

# %%
#importing the client we posted in docker
#we get the database
client = pymongo.MongoClient('mongodb://localhost:27018')
db = client.get_database("prediction_service")

# %%
#e check the client to be sure we are connected
client
# Out:
# MongoClient(host=['localhost:27018'], document_class=dict, tz_aware=False, connect=True)

# %%
db
# Out:
# Database(MongoClient(host=['localhost:27018'], document_class=dict, tz_aware=False, connect=True), 'prediction_service')

# %%
#get collection, which is the name of our collection used in setting up the database 
data_collection = db.get_collection("data")

# %%
#to get the lists 
data = list(data_collection.find())

# %%
#we check the data
data
# Out:
# [{'_id': ObjectId('62ffb2c52cfb8ff11915a51f'),
#   'index': 2048,
#   'squareMeters': 79338,
#   'numberOfRooms': 35,
#   'hasYard': 1,
#   'hasPool': 1,
#   'floors': 80,
#   'cityCode': 64607,
#   'cityPartRange': 7,
#   'numPrevOwners': 3,
#   'made': 2014,
#   'isNewBuilt': 1,
#   'hasStormProtector': 1,
#   'basement': 1908,
#   'attic': 1927,
#   'garage': 447,
#   'hasStorageRoom': 0,
#   'hasGuestRoom': 2,
#   'price': 7943850.4,
#   'category': 'Luxury',
#   'id': '5e5154a7-c306-4d12-af49-8b633566ed8c',
#   'prediction': 7940315},
#  {'_id': ObjectId('62ffb2c62cfb8ff11915a520'),
#   'index': 2067,
#   'squareMeters': 2783,
#   'numberOfRooms': 95,
#   'hasYard': 0,
#   'hasPool': 1,
#   'floors': 42,
#   'cityCode': 33962,
#   'cityPartRange': 9,
#   'numPrevOwners': 5,
#   'made': 2014,
#   'isNewBuilt': 1,
#   'hasStormProtector': 1,
#   'basement': 2993,
#   'attic': 7216,
#   'garage': 905,
#   'hasStorageRoom': 0,
#   'hasGuestRoom': 0,
#   'price': 285274.4,
# ...

# %%
list(data[0])
# Out:
# ['_id',
#  'index',
#  'squareMeters',
#  'numberOfRooms',
#  'hasYard',
#  'hasPool',
#  'floors',
#  'cityCode',
#  'cityPartRange',
#  'numPrevOwners',
#  'made',
#  'isNewBuilt',
#  'hasStormProtector',
#  'basement',
#  'attic',
#  'garage',
#  'hasStorageRoom',
#  'hasGuestRoom',
#  'price',
#  'category',
#  'id',
#  'prediction']

# %%
len(data)
# Out:
# 1502
