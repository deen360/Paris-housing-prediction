# %%
import pymongo

# %%
#importing the client we posted in docker
#we get the database
client = pymongo.MongoClient('mongodb://localhost:27018')
db = client.get_database("prediction_service")

# %%
client
# Out:
# MongoClient(host=['localhost:27018'], document_class=dict, tz_aware=False, connect=True)

# %%
db
# Out:
# Database(MongoClient(host=['localhost:27018'], document_class=dict, tz_aware=False, connect=True), 'prediction_service')

# %%
#get collection 
data_collection = db.get_collection("data")

# %%
#to get the lists 
data = list(data_collection.find())

# %%
#to get the lists 
#dele = data_collection.delete_many({})

# %%
#data = dele

# %%
data
# Out:
# [{'_id': ObjectId('62fce23d54763af87827f78a'),
#   'index': 2048,
#   'squareMeters': 79338,
#   'numberOfRooms': 35,
#   'hasYard': 1,
#   'hasPool': 1,
#   'floors': 80,
#   'cityCode': 64607,
#   'cityPartRange': 7,
#   'numPrevOwners': 3,
#   'made': 2014,
#   'isNewBuilt': 1,
#   'hasStormProtector': 1,
#   'basement': 1908,
#   'attic': 1927,
#   'garage': 447,
#   'hasStorageRoom': 0,
#   'hasGuestRoom': 2,
#   'price': 7943850.4,
#   'category': 'Luxury',
#   'id': '0c010385-3ad8-49b1-a8ca-1d5340830763',
#   'prediction': 7940315},
#  {'_id': ObjectId('62fce23e54763af87827f78b'),
#   'index': 2067,
#   'squareMeters': 2783,
#   'numberOfRooms': 95,
#   'hasYard': 0,
#   'hasPool': 1,
#   'floors': 42,
#   'cityCode': 33962,
#   'cityPartRange': 9,
#   'numPrevOwners': 5,
#   'made': 2014,
#   'isNewBuilt': 1,
#   'hasStormProtector': 1,
#   'basement': 2993,
#   'attic': 7216,
#   'garage': 905,
#   'hasStorageRoom': 0,
#   'hasGuestRoom': 0,
#   'price': 285274.4,
#   'category': 'Basic',
#   'id': '303b4f90-5123-44fd-8399-491e4c264372',
#   'prediction': 284708},
#  {'_id': ObjectId('62fce23f54763af87827f78c'),
#   'index': 1124,
#   'squareMeters': 23210,
#   'numberOfRooms': 4,
#   'hasYard': 0,
#   'hasPool': 0,
#   'floors': 1,
#   'cityCode': 68109,
#   'cityPartRange': 10,
#   'numPrevOwners': 10,
#   'made': 2014,
#   'isNewBuilt': 0,
#   'hasStormProtector': 1,
#   'basement': 4166,
#   'attic': 9902,
#   'garage': 608,
#   'hasStorageRoom': 1,
#   'hasGuestRoom': 3,
#   'price': 2321968.4,
#   'category': 'Basic',
#   'id': 'a760cc5a-8049-47b9-abc8-b21ec62e2fdc',
#   'prediction': 2327437},
#  {'_id': ObjectId('62fce24054763af87827f78d'),
#   'index': 1063,
#   'squareMeters': 71418,
#   'numberOfRooms': 20,
#   'hasYard': 0,
#   'hasPool': 1,
#   'floors': 47,
#   'cityCode': 2634,
#   'cityPartRange': 2,
#   'numPrevOwners': 8,
#   'made': 2014,
#   'isNewBuilt': 1,
#   'hasStormProtector': 1,
#   'basement': 5273,
#   'attic': 3159,
#   'garage': 286,
#   'hasStorageRoom': 1,
#   'hasGuestRoom': 7,
#   'price': 7147130.4,
#   'category': 'Basic',
#   'id': '56a4a8b4-057d-4b5e-adb1-66602e922d4b',
#   'prediction': 7148304},
#  {'_id': ObjectId('62fce24154763af87827f78e'),
#   'index': 806,
#   'squareMeters': 33622,
#   'numberOfRooms': 77,
#   'hasYard': 0,
#   'hasPool': 1,
#   'floors': 73,
#   'cityCode': 93239,
#   'cityPartRange': 7,
#   'numPrevOwners': 5,
#   'made': 2014,
#   'isNewBuilt': 1,
#   'hasStormProtector': 0,
#   'basement': 8902,
#   'attic': 8490,
#   'garage': 340,
#   'hasStorageRoom': 0,
#   'hasGuestRoom': 1,
#   'price': 3371927.4,
#   'category': 'Basic',
#   'id': '5ca36dac-85ca-4672-ac17-9f9dcb8f3a84',
#   'prediction': 3368651},
#  {'_id': ObjectId('62fce24254763af87827f78f'),
#   'index': 4361,
#   'squareMeters': 42586,
#   'numberOfRooms': 54,
#   'hasYard': 1,
#   'hasPool': 1,
#   'floors': 67,
#   'cityCode': 75388,
#   'cityPartRange': 8,
#   'numPrevOwners': 3,
#   'made': 2014,
#   'isNewBuilt': 1,
#   'hasStormProtector': 0,
#   'basement': 5326,
#   'attic': 5962,
#   'garage': 394,
#   'hasStorageRoom': 0,
#   'hasGuestRoom': 10,
#   'price': 4267956.4,
#   'category': 'Luxury',
#   'id': 'f1fc4901-41b6-403b-93f9-f30199283f2d',
#   'prediction': 4265064},
#  {'_id': ObjectId('62fce24354763af87827f790'),
#   'index': 5244,
#   'squareMeters': 61847,
#   'numberOfRooms': 85,
#   'hasYard': 0,
#   'hasPool': 0,
#   'floors': 96,
#   'cityCode': 63056,
#   'cityPartRange': 8,
#   'numPrevOwners': 9,
#   'made': 2014,
#   'isNewBuilt': 1,
#   'hasStormProtector': 0,
#   'basement': 7804,
#   'attic': 9945,
#   'garage': 718,
#   'hasStorageRoom': 0,
#   'hasGuestRoom': 2,
#   'price': 6190109.4,
#   'category': 'Basic',
#   'id': 'fd74fd09-d052-4273-b3df-119771772972',
#   'prediction': 6191191},
#  {'_id': ObjectId('62fce24454763af87827f791'),
#   'index': 4987,
#   'squareMeters': 16467,
#   'numberOfRooms': 84,
#   'hasYard': 1,
#   'hasPool': 1,
#   'floors': 55,
#   'cityCode': 17467,
#   'cityPartRange': 7,
#   'numPrevOwners': 6,
#   'made': 2014,
#   'isNewBuilt': 1,
#   'hasStormProtector': 0,
#   'basement': 6574,
#   'attic': 9098,
#   'garage': 473,
#   'hasStorageRoom': 1,
#   'hasGuestRoom': 3,
#   'price': 1659656.4,
#   'category': 'Luxury',
#   'id': '7ba4a5d1-0389-4500-b9a3-1eb7493c168a',
#   'prediction': 1653128},
#  {'_id': ObjectId('62fce24554763af87827f792'),
#   'index': 8624,
#   'squareMeters': 28915,
#   'numberOfRooms': 37,
#   'hasYard': 1,
#   'hasPool': 0,
#   'floors': 35,
#   'cityCode': 83531,
#   'cityPartRange': 10,
#   'numPrevOwners': 9,
#   'made': 2014,
#   'isNewBuilt': 0,
#   'hasStormProtector': 0,
#   'basement': 4680,
#   'attic': 1402,
#   'garage': 336,
#   'hasStorageRoom': 0,
#   'hasGuestRoom': 4,
#   'price': 2896715.4,
#   'category': 'Basic',
#   'id': '133f2120-7e1b-492f-8cae-452d512e3f9f',
#   'prediction': 2897945},
#  {'_id': ObjectId('62fce24654763af87827f793'),
#   'index': 3895,
#   'squareMeters': 66391,
#   'numberOfRooms': 55,
#   'hasYard': 1,
#   'hasPool': 0,
#   'floors': 94,
#   'cityCode': 21711,
#   'cityPartRange': 3,
#   'numPrevOwners': 10,
#   'made': 2014,
#   'isNewBuilt': 1,
#   'hasStormProtector': 1,
#   'basement': 4667,
#   'attic': 3420,
#   'garage': 740,
#   'hasStorageRoom': 0,
#   'hasGuestRoom': 8,
#   'price': 6650282.4,
#   'category': 'Basic',
#   'id': '377c3302-4ba3-4d87-a9bb-1d8040f3471f',
#   'prediction': 6645597},
#  {'_id': ObjectId('62fce24754763af87827f794'),
#   'index': 3976,
#   'squareMeters': 38633,
#   'numberOfRooms': 75,
#   'hasYard': 1,
#   'hasPool': 1,
#   'floors': 2,
#   'cityCode': 10579,
#   'cityPartRange': 4,
#   'numPrevOwners': 5,
#   'made': 2014,
#   'isNewBuilt': 0,
#   'hasStormProtector': 1,
#   'basement': 9305,
#   'attic': 1088,
#   'garage': 905,
#   'hasStorageRoom': 0,
#   'hasGuestRoom': 3,
#   'price': 3868669.4,
#   'category': 'Basic',
#   'id': 'ac02af34-97f3-485d-8ca8-83825da24a26',
#   'prediction': 3869758},
#  {'_id': ObjectId('62fce24954763af87827f795'),
#   'index': 846,
#   'squareMeters': 82285,
#   'numberOfRooms': 19,
#   'hasYard': 0,
#   'hasPool': 0,
#   'floors': 22,
#   'cityCode': 73045,
#   'cityPartRange': 4,
#   'numPrevOwners': 5,
#   'made': 2014,
#   'isNewBuilt': 0,
#   'hasStormProtector': 0,
#   'basement': 782,
#   'attic': 2211,
#   'garage': 372,
#   'hasStorageRoom': 0,
#   'hasGuestRoom': 8,
#   'price': 8229649.4,
#   'category': 'Basic',
#   'id': '639bd100-93bb-4ca3-8fef-377de790f7d5',
#   'prediction': 8235019},
#  {'_id': ObjectId('62fce24a54763af87827f796'),
#   'index': 7790,
#   'squareMeters': 92151,
#   'numberOfRooms': 67,
#   'hasYard': 1,
#   'hasPool': 0,
#   'floors': 90,
#   'cityCode': 6559,
#   'cityPartRange': 2,
#   'numPrevOwners': 2,
#   'made': 2014,
#   'isNewBuilt': 0,
#   'hasStormProtector': 1,
#   'basement': 7860,
#   'attic': 7803,
#   'garage': 455,
#   'hasStorageRoom': 1,
#   'hasGuestRoom': 5,
#   'price': 9228543.4,
#   'category': 'Basic',
#   'id': '9ae9cda6-6718-4325-bc2a-230132b265ea',
#   'prediction': 9221633},
#  {'_id': ObjectId('62fce24b54763af87827f797'),
#   'index': 8112,
#   'squareMeters': 57243,
#   'numberOfRooms': 22,
#   'hasYard': 1,
#   'hasPool': 1,
#   'floors': 10,
#   'cityCode': 35102,
#   'cityPartRange': 7,
#   'numPrevOwners': 10,
#   'made': 2014,
#   'isNewBuilt': 0,
#   'hasStormProtector': 1,
#   'basement': 2782,
#   'attic': 9257,
#   'garage': 348,
#   'hasStorageRoom': 0,
#   'hasGuestRoom': 2,
#   'price': 5729138.4,
#   'category': 'Basic',
#   'id': 'f3fd903a-cafc-42fd-897d-2aacf351326d',
#   'prediction': 5730784},
#  {'_id': ObjectId('62fce24c54763af87827f798'),
#   'index': 8631,
#   'squareMeters': 44438,
#   'numberOfRooms': 96,
#   'hasYard': 1,
#   'hasPool': 0,
#   'floors': 93,
#   'cityCode': 62393,
#   'cityPartRange': 9,
#   'numPrevOwners': 4,
#   'made': 2014,
#   'isNewBuilt': 1,
#   'hasStormProtector': 1,
#   'basement': 6716,
#   'attic': 7562,
#   'garage': 918,
#   'hasStorageRoom': 0,
#   'hasGuestRoom': 9,
#   'price': 4450823.4,
#   'category': 'Basic',
#   'id': 'a671a280-840f-44d0-9e5e-e34277bb5749',
#   'prediction': 4450267},
#  {'_id': ObjectId('62fce24d54763af87827f799'),
#   'index': 9196,
#   'squareMeters': 40571,
#   'numberOfRooms': 8,
#   'hasYard': 0,
#   'hasPool': 0,
#   'floors': 18,
#   'cityCode': 6526,
#   'cityPartRange': 6,
#   'numPrevOwners': 9,
#   'made': 2014,
#   'isNewBuilt': 1,
#   'hasStormProtector': 0,
#   'basement': 4006,
#   'attic': 7710,
#   'garage': 658,
#   'hasStorageRoom': 1,
#   'hasGuestRoom': 8,
#   'price': 4058935.4,
#   'category': 'Basic',
#   'id': '327d9f9b-73fd-4cc8-976e-eeb678c156e3',
#   'prediction': 4063561},
#  {'_id': ObjectId('62fce24e54763af87827f79a'),
#   'index': 5021,
#   'squareMeters': 98319,
#   'numberOfRooms': 91,
#   'hasYard': 0,
#   'hasPool': 1,
#   'floors': 55,
#   'cityCode': 50885,
#   'cityPartRange': 5,
#   'numPrevOwners': 2,
#   'made': 2014,
#   'isNewBuilt': 0,
#   'hasStormProtector': 1,
#   'basement': 6427,
#   'attic': 2517,
#   'garage': 489,
#   'hasStorageRoom': 1,
#   'hasGuestRoom': 5,
#   'price': 9837654.4,
#   'category': 'Basic',
#   'id': '064714aa-4338-4833-9d79-9c715b49aca7',
#   'prediction': 9838442},
#  {'_id': ObjectId('62fce24f54763af87827f79b'),
#   'index': 7787,
#   'squareMeters': 196,
#   'numberOfRooms': 56,
#   'hasYard': 0,
#   'hasPool': 1,
#   'floors': 98,
#   'cityCode': 53558,
#   'cityPartRange': 8,
#   'numPrevOwners': 6,
#   'made': 2014,
#   'isNewBuilt': 1,
#   'hasStormProtector': 0,
#   'basement': 2663,
#   'attic': 1650,
#   'garage': 403,
#   'hasStorageRoom': 1,
#   'hasGuestRoom': 10,
#   'price': 23818.4,
#   'category': 'Basic',
#   'id': '3abcd66e-9c02-4a4b-992f-d5b9b425e9c7',
#   'prediction': 26005},
#  {'_id': ObjectId('62fce25054763af87827f79c'),
#   'index': 772,
#   'squareMeters': 90180,
#   'numberOfRooms': 91,
#   'hasYard': 1,
#   'hasPool': 0,
#   'floors': 63,
#   'cityCode': 1400,
#   'cityPartRange': 4,
#   'numPrevOwners': 5,
#   'made': 2014,
#   'isNewBuilt': 1,
#   'hasStormProtector': 0,
#   'basement': 9500,
#   'attic': 2033,
#   'garage': 800,
#   'hasStorageRoom': 0,
#   'hasGuestRoom': 8,
#   'price': 9023962.4,
#   'category': 'Basic',
#   'id': '2e94fdf6-730f-4f7a-845b-0eb319390471',
#   'prediction': 9024530},
#  {'_id': ObjectId('62fce25154763af87827f79d'),
#   'index': 8249,
#   'squareMeters': 73693,
#   'numberOfRooms': 12,
#   'hasYard': 1,
#   'hasPool': 0,
#   'floors': 4,
#   'cityCode': 27129,
#   'cityPartRange': 2,
#   'numPrevOwners': 4,
#   'made': 2014,
#   'isNewBuilt': 1,
#   'hasStormProtector': 0,
#   'basement': 2188,
#   'attic': 940,
#   'garage': 147,
#   'hasStorageRoom': 0,
#   'hasGuestRoom': 10,
#   'price': 7373367.4,
#   'category': 'Basic',
#   'id': 'ca9aa466-2c67-4422-adb3-55faf22d2a05',
#   'prediction': 7375807},
#  {'_id': ObjectId('62fce25254763af87827f79e'),
#   'index': 9557,
#   'squareMeters': 87763,
#   'numberOfRooms': 36,
#   'hasYard': 0,
#   'hasPool': 0,
#   'floors': 11,
#   'cityCode': 64490,
#   'cityPartRange': 2,
#   'numPrevOwners': 3,
#   'made': 2014,
#   'isNewBuilt': 0,
#   'hasStormProtector': 0,
#   'basement': 7043,
#   'attic': 300,
#   'garage': 536,
#   'hasStorageRoom': 1,
#   'hasGuestRoom': 8,
#   'price': 8777041.4,
#   'category': 'Basic',
#   'id': '95a1ccd3-1325-438e-9077-9951a66bc35e',
#   'prediction': 8782827},
#  {'_id': ObjectId('62fce25354763af87827f79f'),
#   'index': 8802,
#   'squareMeters': 51419,
#   'numberOfRooms': 91,
#   'hasYard': 1,
#   'hasPool': 0,
#   'floors': 12,
#   'cityCode': 79245,
#   'cityPartRange': 5,
#   'numPrevOwners': 4,
#   'made': 2014,
#   'isNewBuilt': 0,
#   'hasStormProtector': 0,
#   'basement': 2145,
#   'attic': 3160,
#   'garage': 845,
#   'hasStorageRoom': 1,
#   'hasGuestRoom': 8,
#   'price': 5147263.4,
#   'category': 'Basic',
#   'id': 'e11fdf38-077d-4e33-9691-7ee170282ace',
#   'prediction': 5148376},
#  {'_id': ObjectId('62fce25454763af87827f7a0'),
#   'index': 1138,
#   'squareMeters': 28076,
#   'numberOfRooms': 4,
#   'hasYard': 1,
#   'hasPool': 1,
#   'floors': 86,
#   'cityCode': 90966,
#   'cityPartRange': 3,
#   'numPrevOwners': 1,
#   'made': 2014,
#   'isNewBuilt': 0,
#   'hasStormProtector': 1,
#   'basement': 6596,
#   'attic': 8735,
#   'garage': 110,
#   'hasStorageRoom': 0,
#   'hasGuestRoom': 4,
#   'price': 2819687.4,
#   'category': 'Basic',
#   'id': '32f099aa-c688-4915-b157-56ca66b85de5',
#   'prediction': 2814044},
#  {'_id': ObjectId('62fce25554763af87827f7a1'),
#   'index': 2079,
#   'squareMeters': 75762,
#   'numberOfRooms': 87,
#   'hasYard': 0,
#   'hasPool': 0,
#   'floors': 10,
#   'cityCode': 72679,
#   'cityPartRange': 4,
#   'numPrevOwners': 4,
#   'made': 2014,
#   'isNewBuilt': 0,
#   'hasStormProtector': 1,
#   'basement': 9116,
#   'attic': 8746,
#   'garage': 119,
#   'hasStorageRoom': 1,
#   'hasGuestRoom': 8,
#   'price': 7577001.4,
#   'category': 'Basic',
#   'id': 'd111bd97-25d9-40a1-a61a-930dca536638',
#   'prediction': 7582710},
#  {'_id': ObjectId('62fce25654763af87827f7a2'),
#   'index': 1157,
#   'squareMeters': 45206,
#   'numberOfRooms': 39,
#   'hasYard': 1,
#   'hasPool': 1,
#   'floors': 12,
#   'cityCode': 72090,
#   'cityPartRange': 4,
#   'numPrevOwners': 8,
#   'made': 2014,
#   'isNewBuilt': 0,
#   'hasStormProtector': 0,
#   'basement': 2724,
#   'attic': 7920,
#   'garage': 615,
#   'hasStorageRoom': 0,
#   'hasGuestRoom': 1,
#   'price': 4527173.4,
#   'category': 'Basic',
#   'id': '483a8402-095e-49cd-b141-9b8e75217dea',
#   'prediction': 4527068},
#  {'_id': ObjectId('62fce25754763af87827f7a3'),
#   'index': 9525,
#   'squareMeters': 19606,
#   'numberOfRooms': 83,
#   'hasYard': 0,
#   'hasPool': 0,
#   'floors': 23,
#   'cityCode': 30437,
#   'cityPartRange': 3,
#   'numPrevOwners': 7,
#   'made': 2014,
#   'isNewBuilt': 1,
#   'hasStormProtector': 1,
#   'basement': 7491,
#   'attic': 6896,
#   'garage': 327,
#   'hasStorageRoom': 1,
#   'hasGuestRoom': 10,
#   'price': 1961926.4,
#   'category': 'Basic',
#   'id': '39923d46-344a-4808-b7a9-2cec8d791afc',
#   'prediction': 1967032},
#  {'_id': ObjectId('62fce25854763af87827f7a4'),
#   'index': 4007,
#   'squareMeters': 23987,
#   'numberOfRooms': 81,
#   'hasYard': 0,
#   'hasPool': 0,
#   'floors': 23,
#   'cityCode': 27960,
#   'cityPartRange': 1,
#   'numPrevOwners': 2,
#   'made': 2014,
#   'isNewBuilt': 1,
#   'hasStormProtector': 1,
#   'basement': 8434,
#   'attic': 1549,
#   'garage': 809,
#   'hasStorageRoom': 0,
#   'hasGuestRoom': 3,
#   'price': 2399604.4,
#   'category': 'Basic',
#   'id': '45a535e3-164b-4997-9ea3-4e46de9db259',
#   'prediction': 2405138},
#  {'_id': ObjectId('62fce25954763af87827f7a5'),
#   'index': 8226,
#   'squareMeters': 12834,
#   'numberOfRooms': 68,
#   'hasYard': 1,
#   'hasPool': 1,
#   'floors': 74,
#   'cityCode': 14913,
#   'cityPartRange': 4,
#   'numPrevOwners': 2,
#   'made': 2014,
#   'isNewBuilt': 0,
#   'hasStormProtector': 1,
#   'basement': 4960,
#   'attic': 5242,
#   'garage': 579,
#   'hasStorageRoom': 1,
#   'hasGuestRoom': 4,
#   'price': 1293966.4,
#   'category': 'Basic',
#   'id': 'd3cfd7ef-79e5-418a-8aca-52cc9dee8cf9',
#   'prediction': 1289822},
#  {'_id': ObjectId('62fce25a54763af87827f7a6'),
#   'index': 5411,
#   'squareMeters': 86019,
#   'numberOfRooms': 21,
#   'hasYard': 0,
#   'hasPool': 0,
#   'floors': 91,
#   'cityCode': 68445,
#   'cityPartRange': 9,
#   'numPrevOwners': 9,
#   'made': 2014,
#   'isNewBuilt': 1,
#   'hasStormProtector': 0,
#   'basement': 4019,
#   'attic': 1854,
#   'garage': 829,
#   'hasStorageRoom': 1,
#   'hasGuestRoom': 9,
#   'price': 8611760.4,
#   'category': 'Basic',
#   'id': 'c54fd4fb-2034-4a92-8f62-3995bff6cddc',
#   'prediction': 8608425},
#  {'_id': ObjectId('62fce25b54763af87827f7a7'),
#   'index': 591,
#   'squareMeters': 84947,
#   'numberOfRooms': 54,
#   'hasYard': 0,
#   'hasPool': 0,
#   'floors': 68,
#   'cityCode': 53510,
#   'cityPartRange': 5,
#   'numPrevOwners': 7,
#   'made': 2014,
#   'isNewBuilt': 1,
#   'hasStormProtector': 1,
#   'basement': 1588,
#   'attic': 6315,
#   'garage': 675,
#   'hasStorageRoom': 1,
#   'hasGuestRoom': 1,
#   'price': 8498951.4,
#   'category': 'Basic',
#   'id': '39775368-0533-4d93-94cb-d0cc0ced01de',
#   'prediction': 8501223},
#  {'_id': ObjectId('62fce25c54763af87827f7a8'),
#   'index': 1661,
#   'squareMeters': 40846,
#   'numberOfRooms': 23,
#   'hasYard': 1,
#   'hasPool': 1,
#   'floors': 3,
#   'cityCode': 65290,
#   'cityPartRange': 8,
#   'numPrevOwners': 8,
#   'made': 2014,
#   'isNewBuilt': 1,
#   'hasStormProtector': 1,
#   'basement': 8833,
#   'attic': 4877,
#   'garage': 711,
#   'hasStorageRoom': 0,
#   'hasGuestRoom': 0,
#   'price': 4089009.4,
#   'category': 'Luxury',
#   'id': '84c7acd0-e478-43e4-ac3c-a7ed4b86fcc3',
#   'prediction': 4091062},
#  {'_id': ObjectId('62fce25d54763af87827f7a9'),
#   'index': 9512,
#   'squareMeters': 16971,
#   'numberOfRooms': 74,
#   'hasYard': 0,
#   'hasPool': 1,
#   'floors': 35,
#   'cityCode': 93433,
#   'cityPartRange': 10,
#   'numPrevOwners': 3,
#   'made': 2014,
#   'isNewBuilt': 1,
#   'hasStormProtector': 0,
#   'basement': 1873,
#   'attic': 5241,
#   'garage': 744,
#   'hasStorageRoom': 0,
#   'hasGuestRoom': 4,
#   'price': 1705102.4,
#   'category': 'Basic',
#   'id': '99d4d8a4-60aa-43de-903e-38eec647b8a9',
#   'prediction': 1703528},
#  {'_id': ObjectId('62fce25e54763af87827f7aa'),
#   'index': 7735,
#   'squareMeters': 48524,
#   'numberOfRooms': 37,
#   'hasYard': 0,
#   'hasPool': 0,
#   'floors': 77,
#   'cityCode': 33606,
#   'cityPartRange': 8,
#   'numPrevOwners': 10,
#   'made': 2014,
#   'isNewBuilt': 1,
#   'hasStormProtector': 1,
#   'basement': 1957,
#   'attic': 2388,
#   'garage': 383,
#   'hasStorageRoom': 0,
#   'hasGuestRoom': 8,
#   'price': 4858483.4,
#   'category': 'Basic',
#   'id': 'a5c430b6-4ec3-4da5-a365-c8b8c0833ce5',
#   'prediction': 4858872},
#  {'_id': ObjectId('62fce25f54763af87827f7ab'),
#   'index': 4779,
#   'squareMeters': 35127,
#   'numberOfRooms': 8,
#   'hasYard': 0,
#   'hasPool': 0,
#   'floors': 4,
#   'cityCode': 45604,
#   'cityPartRange': 3,
#   'numPrevOwners': 3,
#   'made': 2014,
#   'isNewBuilt': 1,
#   'hasStormProtector': 0,
#   'basement': 9746,
#   'attic': 9694,
#   'garage': 906,
#   'hasStorageRoom': 1,
#   'hasGuestRoom': 2,
#   'price': 3513571.4,
#   'category': 'Basic',
#   'id': '70849507-1e50-4033-a26b-c3b0ee52b420',
#   'prediction': 3519154},
#  {'_id': ObjectId('62fce26054763af87827f7ac'),
#   'index': 7734,
#   'squareMeters': 98258,
#   'numberOfRooms': 16,
#   'hasYard': 1,
#   'hasPool': 0,
#   'floors': 80,
#   'cityCode': 99094,
#   'cityPartRange': 3,
#   'numPrevOwners': 4,
#   'made': 2014,
#   'isNewBuilt': 0,
#   'hasStormProtector': 0,
#   'basement': 1528,
#   'attic': 9438,
#   'garage': 796,
#   'hasStorageRoom': 0,
#   'hasGuestRoom': 2,
#   'price': 9829479.4,
#   'category': 'Basic',
#   'id': 'c8440274-7488-48f8-9503-55ac13182957',
#   'prediction': 9832342},
#  {'_id': ObjectId('62fce26154763af87827f7ad'),
#   'index': 8150,
#   'squareMeters': 92424,
#   'numberOfRooms': 42,
#   'hasYard': 1,
#   'hasPool': 1,
#   'floors': 61,
#   'cityCode': 18819,
#   'cityPartRange': 1,
#   'numPrevOwners': 9,
#   'made': 2014,
#   'isNewBuilt': 0,
#   'hasStormProtector': 0,
#   'basement': 3143,
#   'attic': 8902,
#   'garage': 638,
#   'hasStorageRoom': 0,
#   'hasGuestRoom': 7,
#   'price': 9252356.4,
#   'category': 'Basic',
#   'id': '1d548bc6-36ea-41c2-9d52-de9e7067d161',
#   'prediction': 9248933},
#  {'_id': ObjectId('62fce26254763af87827f7ae'),
#   'index': 5576,
#   'squareMeters': 72554,
#   'numberOfRooms': 16,
#   'hasYard': 0,
#   'hasPool': 1,
#   'floors': 79,
#   'cityCode': 94523,
#   'cityPartRange': 8,
#   'numPrevOwners': 5,
#   'made': 2014,
#   'isNewBuilt': 1,
#   'hasStormProtector': 0,
#   'basement': 8908,
#   'attic': 6398,
#   'garage': 758,
#   'hasStorageRoom': 1,
#   'hasGuestRoom': 9,
#   'price': 7268379.4,
#   'category': 'Basic',
#   'id': '9df7ec51-28a0-45f3-b23e-01ffbeb6e1af',
#   'prediction': 7261906},
#  {'_id': ObjectId('62fce26354763af87827f7af'),
#   'index': 9167,
#   'squareMeters': 21851,
#   'numberOfRooms': 93,
#   'hasYard': 0,
#   'hasPool': 1,
#   'floors': 57,
#   'cityCode': 85169,
#   'cityPartRange': 6,
#   'numPrevOwners': 3,
#   'made': 2014,
#   'isNewBuilt': 0,
#   'hasStormProtector': 0,
#   'basement': 1607,
#   'attic': 8377,
#   'garage': 168,
#   'hasStorageRoom': 1,
#   'hasGuestRoom': 2,
#   'price': 2188090.4,
#   'category': 'Basic',
#   'id': 'b32bac9b-37e6-4099-af4c-61c622173899',
#   'prediction': 2191535},
#  {'_id': ObjectId('62fce26454763af87827f7b0'),
#   'index': 1106,
#   'squareMeters': 26223,
#   'numberOfRooms': 35,
#   'hasYard': 1,
#   'hasPool': 1,
#   'floors': 8,
#   'cityCode': 53223,
#   'cityPartRange': 3,
#   'numPrevOwners': 6,
#   'made': 2014,
#   'isNewBuilt': 1,
#   'hasStormProtector': 1,
#   'basement': 1084,
#   'attic': 7324,
#   'garage': 195,
#   'hasStorageRoom': 0,
#   'hasGuestRoom': 5,
#   'price': 2630045.4,
#   'category': 'Luxury',
#   'id': '5339e594-a7ee-44aa-862c-2244bee1808c',
#   'prediction': 2628741},
#  {'_id': ObjectId('62fce26554763af87827f7b1'),
#   'index': 4446,
#   'squareMeters': 67510,
#   'numberOfRooms': 32,
#   'hasYard': 1,
#   'hasPool': 1,
#   'floors': 61,
#   'cityCode': 22236,
#   'cityPartRange': 1,
#   'numPrevOwners': 7,
#   'made': 2014,
#   'isNewBuilt': 0,
#   'hasStormProtector': 1,
#   'basement': 6018,
#   'attic': 7718,
#   'garage': 643,
#   'hasStorageRoom': 0,
#   'hasGuestRoom': 9,
#   'price': 6758961.4,
#   'category': 'Basic',
#   'id': 'ba6aa369-1dff-4419-a0cc-dfaccd9ca247',
#   'prediction': 6757499},
#  {'_id': ObjectId('62fce26654763af87827f7b2'),
#   'index': 3995,
#   'squareMeters': 48736,
#   'numberOfRooms': 97,
#   'hasYard': 1,
#   'hasPool': 1,
#   'floors': 89,
#   'cityCode': 86292,
#   'cityPartRange': 10,
#   'numPrevOwners': 3,
#   'made': 2014,
#   'isNewBuilt': 0,
#   'hasStormProtector': 0,
#   'basement': 167,
#   'attic': 6075,
#   'garage': 139,
#   'hasStorageRoom': 0,
#   'hasGuestRoom': 0,
#   'price': 4885719.4,
#   'category': 'Basic',
#   'id': 'f804ecdd-ced6-481d-b30d-30b9f7ffdeae',
#   'prediction': 4880073},
#  {'_id': ObjectId('62fce26754763af87827f7b3'),
#   'index': 5405,
#   'squareMeters': 74265,
#   'numberOfRooms': 33,
#   'hasYard': 1,
#   'hasPool': 0,
#   'floors': 87,
#   'cityCode': 79197,
#   'cityPartRange': 5,
#   'numPrevOwners': 10,
#   'made': 2014,
#   'isNewBuilt': 1,
#   'hasStormProtector': 1,
#   'basement': 2985,
#   'attic': 4358,
#   'garage': 777,
#   'hasStorageRoom': 1,
#   'hasGuestRoom': 6,
#   'price': 7437378.4,
#   'category': 'Basic',
#   'id': 'd0cfab58-c82d-499d-8aef-33f1cf6919d0',
#   'prediction': 7433008},
#  {'_id': ObjectId('62fce26854763af87827f7b4'),
#   'index': 7725,
#   'squareMeters': 42674,
#   'numberOfRooms': 36,
#   'hasYard': 0,
#   'hasPool': 1,
#   'floors': 5,
#   'cityCode': 9068,
#   'cityPartRange': 3,
#   'numPrevOwners': 3,
#   'made': 2014,
#   'isNewBuilt': 1,
#   'hasStormProtector': 1,
#   'basement': 4636,
#   'attic': 286,
#   'garage': 177,
#   'hasStorageRoom': 0,
#   'hasGuestRoom': 7,
#   'price': 4269275.4,
#   'category': 'Basic',
#   'id': '266062ce-007d-4f69-b4cc-7faa02a64283',
#   'prediction': 4273864},
#  {'_id': ObjectId('62fce26954763af87827f7b5'),
#   'index': 1194,
#   'squareMeters': 82202,
#   'numberOfRooms': 100,
#   'hasYard': 0,
#   'hasPool': 1,
#   'floors': 59,
#   'cityCode': 47682,
#   'cityPartRange': 8,
#   'numPrevOwners': 2,
#   'made': 2014,
#   'isNewBuilt': 1,
#   'hasStormProtector': 1,
#   'basement': 3857,
#   'attic': 2418,
#   'garage': 326,
#   'hasStorageRoom': 0,
#   'hasGuestRoom': 7,
#   'price': 8227582.4,
#   'category': 'Basic',
#   'id': '4702d13b-a99c-400e-9cd5-cfa4bb75d0cf',
#   'prediction': 8226719},
#  {'_id': ObjectId('62fce26a54763af87827f7b6'),
#   'index': 1081,
#   'squareMeters': 9457,
#   'numberOfRooms': 70,
#   'hasYard': 0,
#   'hasPool': 1,
#   'floors': 37,
#   'cityCode': 98638,
#   'cityPartRange': 1,
#   'numPrevOwners': 2,
#   'made': 2014,
#   'isNewBuilt': 1,
#   'hasStormProtector': 1,
#   'basement': 3606,
#   'attic': 5244,
#   'garage': 425,
#   'hasStorageRoom': 0,
#   'hasGuestRoom': 9,
#   'price': 953108.4,
#   'category': 'Basic',
#   'id': 'a8e67075-3b35-4944-acb4-80ba3b222c60',
#   'prediction': 952118},
#  {'_id': ObjectId('62fce26c54763af87827f7b7'),
#   'index': 1644,
#   'squareMeters': 13550,
#   'numberOfRooms': 43,
#   'hasYard': 1,
#   'hasPool': 0,
#   'floors': 37,
#   'cityCode': 43418,
#   'cityPartRange': 8,
#   'numPrevOwners': 2,
#   'made': 2014,
#   'isNewBuilt': 1,
#   'hasStormProtector': 0,
#   'basement': 2437,
#   'attic': 4308,
#   'garage': 326,
#   'hasStorageRoom': 1,
#   'hasGuestRoom': 6,
#   'price': 1362271.4,
#   'category': 'Basic',
#   'id': '09eed0c9-e7a4-4ab9-a78d-5f03c70b1ac0',
#   'prediction': 1361423},
#  {'_id': ObjectId('62fce26d54763af87827f7b8'),
#   'index': 9174,
#   'squareMeters': 41880,
#   'numberOfRooms': 55,
#   'hasYard': 0,
#   'hasPool': 1,
#   'floors': 87,
#   'cityCode': 28219,
#   'cityPartRange': 9,
#   'numPrevOwners': 5,
#   'made': 2014,
#   'isNewBuilt': 0,
#   'hasStormProtector': 0,
#   'basement': 9227,
#   'attic': 4688,
#   'garage': 211,
#   'hasStorageRoom': 0,
#   'hasGuestRoom': 2,
#   'price': 4192229.4,
#   'category': 'Basic',
#   'id': '2461d3b8-8915-4673-8364-61a6c1b9575a',
#   'prediction': 4194463},
#  {'_id': ObjectId('62fce26e54763af87827f7b9'),
#   'index': 5373,
#   'squareMeters': 33814,
#   'numberOfRooms': 70,
#   'hasYard': 0,
#   'hasPool': 1,
#   'floors': 63,
#   'cityCode': 64240,
#   'cityPartRange': 8,
#   'numPrevOwners': 6,
#   'made': 2014,
#   'isNewBuilt': 1,
#   'hasStormProtector': 0,
#   'basement': 3128,
#   'attic': 8963,
#   'garage': 328,
#   'hasStorageRoom': 1,
#   'hasGuestRoom': 4,
#   'price': 3390442.4,
#   'category': 'Basic',
#   'id': '7bb329d4-b70e-42cc-9b1a-4325357d2214',
#   'prediction': 3387852},
#  {'_id': ObjectId('62fce26f54763af87827f7ba'),
#   'index': 5583,
#   'squareMeters': 16625,
#   'numberOfRooms': 27,
#   'hasYard': 0,
#   'hasPool': 0,
#   'floors': 8,
#   'cityCode': 57906,
#   'cityPartRange': 9,
#   'numPrevOwners': 9,
#   'made': 2014,
#   'isNewBuilt': 1,
#   'hasStormProtector': 1,
#   'basement': 1946,
#   'attic': 2358,
#   'garage': 545,
#   'hasStorageRoom': 0,
#   'hasGuestRoom': 7,
#   'price': 1664023.4,
#   'category': 'Basic',
#   'id': 'b63f2d49-e71c-4eb2-952a-8dbdcc34178d',
#   'prediction': 1668928},
#  {'_id': ObjectId('62fce27054763af87827f7bb'),
#   'index': 9122,
#   'squareMeters': 85104,
#   'numberOfRooms': 7,
#   'hasYard': 1,
#   'hasPool': 0,
#   'floors': 37,
#   'cityCode': 23443,
#   'cityPartRange': 9,
#   'numPrevOwners': 6,
#   'made': 2014,
#   'isNewBuilt': 1,
#   'hasStormProtector': 1,
#   'basement': 4537,
#   'attic': 5629,
#   'garage': 103,
#   'hasStorageRoom': 1,
#   'hasGuestRoom': 2,
#   'price': 8517206.4,
#   'category': 'Basic',
#   'id': '90edf4d2-7cf9-410b-b641-4a83f9809d0a',
#   'prediction': 8516923},
#  {'_id': ObjectId('62fce27154763af87827f7bc'),
#   'index': 9444,
#   'squareMeters': 92256,
#   'numberOfRooms': 32,
#   'hasYard': 0,
#   'hasPool': 1,
#   'floors': 35,
#   'cityCode': 73315,
#   'cityPartRange': 10,
#   'numPrevOwners': 1,
#   'made': 2014,
#   'isNewBuilt': 0,
#   'hasStormProtector': 1,
#   'basement': 8875,
#   'attic': 570,
#   'garage': 582,
#   'hasStorageRoom': 0,
#   'hasGuestRoom': 1,
#   'price': 9231273.4,
#   'category': 'Basic',
#   'id': '5f4336b0-96eb-4ef8-a361-048a43d0a8ad',
#   'prediction': 9232133},
#  {'_id': ObjectId('62fce27254763af87827f7bd'),
#   'index': 9132,
#   'squareMeters': 78882,
#   'numberOfRooms': 100,
#   'hasYard': 1,
#   'hasPool': 0,
#   'floors': 63,
#   'cityCode': 73080,
#   'cityPartRange': 10,
#   'numPrevOwners': 8,
#   'made': 2014,
#   'isNewBuilt': 0,
#   'hasStormProtector': 1,
#   'basement': 6371,
#   'attic': 5019,
#   'garage': 134,
#   'hasStorageRoom': 0,
#   'hasGuestRoom': 6,
#   'price': 7893540.4,
#   'category': 'Basic',
#   'id': 'fcd44145-ce60-4349-9098-7879db2cc79c',
#   'prediction': 7894715},
#  {'_id': ObjectId('62fce27354763af87827f7be'),
#   'index': 8746,
#   'squareMeters': 59437,
#   'numberOfRooms': 75,
#   'hasYard': 1,
#   'hasPool': 1,
#   'floors': 60,
#   'cityCode': 57505,
#   'cityPartRange': 2,
#   'numPrevOwners': 10,
#   'made': 2014,
#   'isNewBuilt': 1,
#   'hasStormProtector': 1,
#   'basement': 1716,
#   'attic': 534,
#   'garage': 455,
#   'hasStorageRoom': 1,
#   'hasGuestRoom': 9,
#   'price': 5952617.4,
#   'category': 'Luxury',
#   'id': '7992db6c-fe2e-44d9-95b9-e11b909d59dd',
#   'prediction': 5950187},
#  {'_id': ObjectId('62fce27454763af87827f7bf'),
#   'index': 450,
#   'squareMeters': 94951,
#   'numberOfRooms': 52,
#   'hasYard': 0,
#   'hasPool': 1,
#   'floors': 80,
#   'cityCode': 45083,
#   'cityPartRange': 8,
#   'numPrevOwners': 4,
#   'made': 2014,
#   'isNewBuilt': 1,
#   'hasStormProtector': 1,
#   'basement': 4121,
#   'attic': 3981,
#   'garage': 261,
#   'hasStorageRoom': 1,
#   'hasGuestRoom': 3,
#   'price': 9498811.4,
#   'category': 'Basic',
#   'id': '28929b6a-9290-45cb-8d03-f8525eed539a',
#   'prediction': 9501637},
#  {'_id': ObjectId('62fce27554763af87827f7c0'),
#   'index': 9181,
#   'squareMeters': 80206,
#   'numberOfRooms': 28,
#   'hasYard': 0,
#   'hasPool': 1,
#   'floors': 42,
#   'cityCode': 13253,
#   'cityPartRange': 10,
#   'numPrevOwners': 4,
#   'made': 2014,
#   'isNewBuilt': 0,
#   'hasStormProtector': 1,
#   'basement': 4620,
#   'attic': 6153,
#   'garage': 854,
#   'hasStorageRoom': 1,
#   'hasGuestRoom': 10,
#   'price': 8027224.4,
#   'category': 'Basic',
#   'id': '1f9b1a54-d6c2-40f2-99be-1c97d25bc8c4',
#   'prediction': 8027116},
#  {'_id': ObjectId('62fce27654763af87827f7c1'),
#   'index': 5689,
#   'squareMeters': 42981,
#   'numberOfRooms': 49,
#   'hasYard': 0,
#   'hasPool': 0,
#   'floors': 73,
#   'cityCode': 18351,
#   'cityPartRange': 10,
#   'numPrevOwners': 5,
#   'made': 2014,
#   'isNewBuilt': 0,
#   'hasStormProtector': 1,
#   'basement': 7819,
#   'attic': 3219,
#   'garage': 785,
#   'hasStorageRoom': 0,
#   'hasGuestRoom': 10,
#   'price': 4300680.4,
#   'category': 'Basic',
#   'id': 'e1018dd5-08db-4d3d-a610-20e100288d20',
#   'prediction': 4304565},
#  {'_id': ObjectId('62fce27754763af87827f7c2'),
#   'index': 2000,
#   'squareMeters': 77747,
#   'numberOfRooms': 50,
#   'hasYard': 1,
#   'hasPool': 1,
#   'floors': 72,
#   'cityCode': 98938,
#   'cityPartRange': 8,
#   'numPrevOwners': 10,
#   'made': 2014,
#   'isNewBuilt': 0,
#   'hasStormProtector': 1,
#   'basement': 4829,
#   'attic': 4204,
#   'garage': 455,
#   'hasStorageRoom': 0,
#   'hasGuestRoom': 3,
#   'price': 7786197.4,
#   'category': 'Basic',
#   'id': '45219975-9ee2-4d65-8732-dcd3ba88b10c',
#   'prediction': 7781213},
#  {'_id': ObjectId('62fce27854763af87827f7c3'),
#   'index': 1718,
#   'squareMeters': 43905,
#   'numberOfRooms': 58,
#   'hasYard': 0,
#   'hasPool': 1,
#   'floors': 49,
#   'cityCode': 77800,
#   'cityPartRange': 3,
#   'numPrevOwners': 9,
#   'made': 2014,
#   'isNewBuilt': 1,
#   'hasStormProtector': 1,
#   'basement': 1108,
#   'attic': 8561,
#   'garage': 191,
#   'hasStorageRoom': 1,
#   'hasGuestRoom': 4,
#   'price': 4396172.4,
#   'category': 'Basic',
#   'id': '44651269-d8bd-44ad-82f3-531cabce1fb7',
#   'prediction': 4396966},
#  {'_id': ObjectId('62fce27954763af87827f7c4'),
#   'index': 788,
#   'squareMeters': 78984,
#   'numberOfRooms': 62,
#   'hasYard': 1,
#   'hasPool': 1,
#   'floors': 89,
#   'cityCode': 57806,
#   'cityPartRange': 9,
#   'numPrevOwners': 9,
#   'made': 2014,
#   'isNewBuilt': 0,
#   'hasStormProtector': 1,
#   'basement': 1199,
#   'attic': 9487,
#   'garage': 165,
#   'hasStorageRoom': 1,
#   'hasGuestRoom': 2,
#   'price': 7910102.4,
#   'category': 'Basic',
#   'id': '1a2f3bca-eae0-4842-9002-a33bc557a773',
#   'prediction': 7904915},
#  {'_id': ObjectId('62fce27a54763af87827f7c5'),
#   'index': 1716,
#   'squareMeters': 16006,
#   'numberOfRooms': 64,
#   'hasYard': 1,
#   'hasPool': 0,
#   'floors': 81,
#   'cityCode': 51164,
#   'cityPartRange': 8,
#   'numPrevOwners': 7,
#   'made': 2014,
#   'isNewBuilt': 1,
#   'hasStormProtector': 1,
#   'basement': 5205,
#   'attic': 4975,
#   'garage': 431,
#   'hasStorageRoom': 0,
#   'hasGuestRoom': 9,
#   'price': 1606879.4,
#   'category': 'Basic',
#   'id': 'a7c3c39e-71a5-4328-861f-0fcdf697f5c3',
#   'prediction': 1607027},
#  {'_id': ObjectId('62fce27b54763af87827f7c6'),
#   'index': 7755,
#   'squareMeters': 87685,
#   'numberOfRooms': 37,
#   'hasYard': 0,
#   'hasPool': 1,
#   'floors': 29,
#   'cityCode': 36296,
#   'cityPartRange': 2,
#   'numPrevOwners': 9,
#   'made': 2014,
#   'isNewBuilt': 1,
#   'hasStormProtector': 0,
#   'basement': 2948,
#   'attic': 3061,
#   'garage': 988,
#   'hasStorageRoom': 1,
#   'hasGuestRoom': 10,
#   'price': 8772035.4,
#   'category': 'Basic',
#   'id': 'a6d8f93a-aa6d-40ee-89d1-6358f9b1220d',
#   'prediction': 8775027},
#  {'_id': ObjectId('62fce27c54763af87827f7c7'),
#   'index': 1713,
#   'squareMeters': 40806,
#   'numberOfRooms': 34,
#   'hasYard': 1,
#   'hasPool': 1,
#   'floors': 71,
#   'cityCode': 30320,
#   'cityPartRange': 9,
#   'numPrevOwners': 7,
#   'made': 2014,
#   'isNewBuilt': 0,
#   'hasStormProtector': 1,
#   'basement': 6778,
#   'attic': 779,
#   'garage': 716,
#   'hasStorageRoom': 1,
#   'hasGuestRoom': 7,
#   'price': 4089457.4,
#   'category': 'Basic',
#   'id': 'c70bb386-e759-405a-a858-b29cb7498d4f',
#   'prediction': 4087061},
#  {'_id': ObjectId('62fce27d54763af87827f7c8'),
#   'index': 577,
#   'squareMeters': 55707,
#   'numberOfRooms': 7,
#   'hasYard': 0,
#   'hasPool': 0,
#   'floors': 33,
#   'cityCode': 55496,
#   'cityPartRange': 5,
#   'numPrevOwners': 7,
#   'made': 2014,
#   'isNewBuilt': 0,
#   'hasStormProtector': 1,
#   'basement': 9279,
#   'attic': 1236,
#   'garage': 417,
#   'hasStorageRoom': 1,
#   'hasGuestRoom': 3,
#   'price': 5573001.4,
#   'category': 'Basic',
#   'id': 'de78abc1-7e79-41d5-861b-4cb18b4c1020',
#   'prediction': 5577182},
#  {'_id': ObjectId('62fce27e54763af87827f7c9'),
#   'index': 5560,
#   'squareMeters': 41057,
#   'numberOfRooms': 22,
#   'hasYard': 0,
#   'hasPool': 0,
#   'floors': 18,
#   'cityCode': 7613,
#   'cityPartRange': 9,
#   'numPrevOwners': 3,
#   'made': 2014,
#   'isNewBuilt': 0,
#   'hasStormProtector': 1,
#   'basement': 449,
#   'attic': 5255,
#   'garage': 162,
#   'hasStorageRoom': 1,
#   'hasGuestRoom': 3,
#   'price': 4106731.4,
#   'category': 'Basic',
#   'id': '6c67e131-f57c-4f95-b993-4a22b594b0ab',
#   'prediction': 4112162},
#  {'_id': ObjectId('62fce27f54763af87827f7ca'),
#   'index': 4140,
#   'squareMeters': 42969,
#   'numberOfRooms': 41,
#   'hasYard': 0,
#   'hasPool': 0,
#   'floors': 65,
#   'cityCode': 58871,
#   'cityPartRange': 6,
#   'numPrevOwners': 10,
#   'made': 2014,
#   'isNewBuilt': 0,
#   'hasStormProtector': 0,
#   'basement': 5637,
#   'attic': 3120,
#   'garage': 400,
#   'hasStorageRoom': 1,
#   'hasGuestRoom': 8,
#   'price': 4301496.4,
#   'category': 'Basic',
#   'id': 'bfb32493-cd57-445c-b7d6-adbef8d3213a',
#   'prediction': 4303364},
#  {'_id': ObjectId('62fce28054763af87827f7cb'),
#   'index': 4914,
#   'squareMeters': 25307,
#   'numberOfRooms': 24,
#   'hasYard': 1,
#   'hasPool': 0,
#   'floors': 90,
#   'cityCode': 73502,
#   'cityPartRange': 1,
#   'numPrevOwners': 5,
#   'made': 2014,
#   'isNewBuilt': 0,
#   'hasStormProtector': 0,
#   'basement': 9536,
#   'attic': 4979,
#   'garage': 381,
#   'hasStorageRoom': 1,
#   'hasGuestRoom': 5,
#   'price': 2538791.4,
#   'category': 'Basic',
#   'id': 'b1a7620a-6bfb-4ea5-b5bd-de187bf62b3c',
#   'prediction': 2537140},
#  {'_id': ObjectId('62fce28154763af87827f7cc'),
#   'index': 1121,
#   'squareMeters': 69945,
#   'numberOfRooms': 5,
#   'hasYard': 0,
#   'hasPool': 0,
#   'floors': 77,
#   'cityCode': 26679,
#   'cityPartRange': 4,
#   'numPrevOwners': 8,
#   'made': 2014,
#   'isNewBuilt': 0,
#   'hasStormProtector': 0,
#   'basement': 8796,
#   'attic': 4073,
#   'garage': 924,
#   'hasStorageRoom': 0,
#   'hasGuestRoom': 10,
#   'price': 6998212.4,
#   'category': 'Basic',
#   'id': '98a69c54-6383-442c-8a10-7bf9936d7bbb',
#   'prediction': 7001002},
#  {'_id': ObjectId('62fce28254763af87827f7cd'),
#   'index': 1503,
#   'squareMeters': 98403,
#   'numberOfRooms': 87,
#   'hasYard': 1,
#   'hasPool': 1,
#   'floors': 10,
#   'cityCode': 74330,
#   'cityPartRange': 8,
#   'numPrevOwners': 6,
#   'made': 2014,
#   'isNewBuilt': 1,
#   'hasStormProtector': 1,
#   'basement': 2823,
#   'attic': 2933,
#   'garage': 399,
#   'hasStorageRoom': 0,
#   'hasGuestRoom': 7,
#   'price': 9847192.4,
#   'category': 'Luxury',
#   'id': '6de91e8d-ba9d-4f27-87c2-59c5d204f144',
#   'prediction': 9846842},
#  {'_id': ObjectId('62fce28354763af87827f7ce'),
#   'index': 500,
#   'squareMeters': 8977,
#   'numberOfRooms': 53,
#   'hasYard': 0,
#   'hasPool': 1,
#   'floors': 62,
#   'cityCode': 91218,
#   'cityPartRange': 1,
#   'numPrevOwners': 3,
#   'made': 2014,
#   'isNewBuilt': 0,
#   'hasStormProtector': 0,
#   'basement': 5865,
#   'attic': 7112,
#   'garage': 250,
#   'hasStorageRoom': 1,
#   'hasGuestRoom': 5,
#   'price': 905963.4,
#   'category': 'Basic',
#   'id': 'aa285a5f-730d-481b-8f8d-1a1cff4d1114',
#   'prediction': 904117},
#  {'_id': ObjectId('62fce28454763af87827f7cf'),
#   'index': 9344,
#   'squareMeters': 80282,
#   'numberOfRooms': 22,
#   'hasYard': 1,
#   'hasPool': 0,
#   'floors': 37,
#   'cityCode': 43212,
#   'cityPartRange': 3,
#   'numPrevOwners': 2,
#   'made': 2014,
#   'isNewBuilt': 0,
#   'hasStormProtector': 1,
#   'basement': 9027,
#   'attic': 9713,
#   'garage': 338,
#   'hasStorageRoom': 0,
#   'hasGuestRoom': 0,
#   'price': 8034878.4,
#   'category': 'Basic',
#   'id': 'ea7d840f-79f8-433f-bb99-070d499a7f51',
#   'prediction': 8034717},
#  {'_id': ObjectId('62fce28554763af87827f7d0'),
#   'index': 677,
#   'squareMeters': 8808,
#   'numberOfRooms': 9,
#   'hasYard': 1,
#   'hasPool': 1,
#   'floors': 15,
#   'cityCode': 13333,
#   'cityPartRange': 2,
#   'numPrevOwners': 9,
#   'made': 2014,
#   'isNewBuilt': 0,
#   'hasStormProtector': 0,
#   'basement': 7170,
#   'attic': 1020,
#   'garage': 397,
#   'hasStorageRoom': 1,
#   'hasGuestRoom': 7,
#   'price': 887645.4,
#   'category': 'Basic',
#   'id': '9fd686a6-56e7-4ee7-87dd-10bcf4c4677d',
#   'prediction': 887217},
#  {'_id': ObjectId('62fce28654763af87827f7d1'),
#   'index': 877,
#   'squareMeters': 71661,
#   'numberOfRooms': 54,
#   'hasYard': 0,
#   'hasPool': 1,
#   'floors': 64,
#   'cityCode': 30637,
#   'cityPartRange': 1,
#   'numPrevOwners': 6,
#   'made': 2014,
#   'isNewBuilt': 1,
#   'hasStormProtector': 0,
#   'basement': 793,
#   'attic': 3709,
#   'garage': 516,
#   'hasStorageRoom': 0,
#   'hasGuestRoom': 2,
#   'price': 7173346.4,
#   'category': 'Basic',
#   'id': '63d2ac8b-d068-4abf-a272-f3679745ada6',
#   'prediction': 7172604},
#  {'_id': ObjectId('62fce28754763af87827f7d2'),
#   'index': 9286,
#   'squareMeters': 14611,
#   'numberOfRooms': 94,
#   'hasYard': 0,
#   'hasPool': 1,
#   'floors': 48,
#   'cityCode': 33314,
#   'cityPartRange': 9,
#   'numPrevOwners': 3,
#   'made': 2014,
#   'isNewBuilt': 1,
#   'hasStormProtector': 0,
#   'basement': 3271,
#   'attic': 2658,
#   'garage': 655,
#   'hasStorageRoom': 1,
#   'hasGuestRoom': 3,
#   'price': 1468749.4,
#   'category': 'Basic',
#   'id': '7d76ea53-6a25-4ca8-b35e-8cee4a792cca',
#   'prediction': 1467525},
#  {'_id': ObjectId('62fce28854763af87827f7d3'),
#   'index': 1432,
#   'squareMeters': 88441,
#   'numberOfRooms': 86,
#   'hasYard': 1,
#   'hasPool': 1,
#   'floors': 65,
#   'cityCode': 38191,
#   'cityPartRange': 1,
#   'numPrevOwners': 9,
#   'made': 2014,
#   'isNewBuilt': 1,
#   'hasStormProtector': 0,
#   'basement': 6096,
#   'attic': 8178,
#   'garage': 639,
#   'hasStorageRoom': 1,
#   'hasGuestRoom': 10,
#   'price': 8854284.4,
#   'category': 'Luxury',
#   'id': '0f880f17-b4f7-47f1-b3cb-0d7e395f9b6c',
#   'prediction': 8850628},
#  {'_id': ObjectId('62fce28954763af87827f7d4'),
#   'index': 3943,
#   'squareMeters': 98788,
#   'numberOfRooms': 27,
#   'hasYard': 1,
#   'hasPool': 0,
#   'floors': 25,
#   'cityCode': 4206,
#   'cityPartRange': 5,
#   'numPrevOwners': 9,
#   'made': 2014,
#   'isNewBuilt': 1,
#   'hasStormProtector': 0,
#   'basement': 5205,
#   'attic': 5002,
#   'garage': 278,
#   'hasStorageRoom': 1,
#   'hasGuestRoom': 3,
#   'price': 9884496.4,
#   'category': 'Basic',
#   'id': '4b59857b-8d7d-4b2a-9b61-9c9af37d8af8',
#   'prediction': 9885342},
#  {'_id': ObjectId('62fce28a54763af87827f7d5'),
#   'index': 1429,
#   'squareMeters': 11986,
#   'numberOfRooms': 9,
#   'hasYard': 1,
#   'hasPool': 0,
#   'floors': 100,
#   'cityCode': 45263,
#   'cityPartRange': 4,
#   'numPrevOwners': 1,
#   'made': 2014,
#   'isNewBuilt': 1,
#   'hasStormProtector': 0,
#   'basement': 1441,
#   'attic': 5355,
#   'garage': 770,
#   'hasStorageRoom': 0,
#   'hasGuestRoom': 9,
#   'price': 1207946.4,
#   'category': 'Basic',
#   'id': '9fe818b3-2bbc-4bbb-b0fd-ecb858de16b8',
#   'prediction': 1205021},
#  {'_id': ObjectId('62fce28b54763af87827f7d6'),
#   'index': 5509,
#   'squareMeters': 90947,
#   'numberOfRooms': 89,
#   'hasYard': 1,
#   'hasPool': 1,
#   'floors': 61,
#   'cityCode': 64161,
#   'cityPartRange': 2,
#   'numPrevOwners': 6,
#   'made': 2014,
#   'isNewBuilt': 0,
#   'hasStormProtector': 1,
#   'basement': 5886,
#   'attic': 1712,
#   'garage': 225,
#   'hasStorageRoom': 1,
#   'hasGuestRoom': 1,
#   'price': 9103454.4,
#   'category': 'Basic',
#   'id': 'ed0bbc6d-9e2a-420d-8c74-043cf900c1d2',
#   'prediction': 9101231},
#  {'_id': ObjectId('62fce28c54763af87827f7d7'),
#   'index': 4080,
#   'squareMeters': 43400,
#   'numberOfRooms': 41,
#   'hasYard': 1,
#   'hasPool': 1,
#   'floors': 72,
#   'cityCode': 88811,
#   'cityPartRange': 7,
#   'numPrevOwners': 9,
#   'made': 2014,
#   'isNewBuilt': 0,
#   'hasStormProtector': 0,
#   'basement': 2849,
#   'attic': 5182,
#   'garage': 331,
#   'hasStorageRoom': 1,
#   'hasGuestRoom': 7,
#   'price': 4350109.4,
#   'category': 'Basic',
#   'id': '0a909ed6-3e60-42ad-a4e1-394962d37a88',
#   'prediction': 4346465},
#  {'_id': ObjectId('62fce28d54763af87827f7d8'),
#   'index': 8490,
#   'squareMeters': 33628,
#   'numberOfRooms': 100,
#   'hasYard': 0,
#   'hasPool': 0,
#   'floors': 43,
#   'cityCode': 17190,
#   'cityPartRange': 10,
#   'numPrevOwners': 9,
#   'made': 2014,
#   'isNewBuilt': 1,
#   'hasStormProtector': 1,
#   'basement': 9961,
#   'attic': 9248,
#   'garage': 166,
#   'hasStorageRoom': 0,
#   'hasGuestRoom': 10,
#   'price': 3367900.4,
#   'category': 'Basic',
#   'id': 'df80ff01-8397-41a0-b044-98e8880fe6b1',
#   'prediction': 3369251},
#  {'_id': ObjectId('62fce28e54763af87827f7d9'),
#   'index': 4191,
#   'squareMeters': 49904,
#   'numberOfRooms': 92,
#   'hasYard': 0,
#   'hasPool': 0,
#   'floors': 90,
#   'cityCode': 96283,
#   'cityPartRange': 8,
#   'numPrevOwners': 9,
#   'made': 2014,
#   'isNewBuilt': 1,
#   'hasStormProtector': 0,
#   'basement': 8810,
#   'attic': 4176,
#   'garage': 431,
#   'hasStorageRoom': 0,
#   'hasGuestRoom': 0,
#   'price': 4998671.4,
#   'category': 'Basic',
#   'id': '38c42453-647a-42c5-84c8-f47d30022cb3',
#   'prediction': 4996874},
#  {'_id': ObjectId('62fce29054763af87827f7da'),
#   'index': 4036,
#   'squareMeters': 73441,
#   'numberOfRooms': 90,
#   'hasYard': 1,
#   'hasPool': 1,
#   'floors': 82,
#   'cityCode': 96436,
#   'cityPartRange': 3,
#   'numPrevOwners': 2,
#   'made': 2014,
#   'isNewBuilt': 1,
#   'hasStormProtector': 0,
#   'basement': 8391,
#   'attic': 569,
#   'garage': 565,
#   'hasStorageRoom': 1,
#   'hasGuestRoom': 2,
#   'price': 7352484.4,
#   'category': 'Luxury',
#   'id': 'f9eb1f8d-aefb-4b34-9332-fe84701cae48',
#   'prediction': 7350607},
#  {'_id': ObjectId('62fce29154763af87827f7db'),
#   'index': 8022,
#   'squareMeters': 18244,
#   'numberOfRooms': 9,
#   'hasYard': 1,
#   'hasPool': 0,
#   'floors': 24,
#   'cityCode': 65448,
#   'cityPartRange': 3,
#   'numPrevOwners': 5,
#   'made': 2014,
#   'isNewBuilt': 0,
#   'hasStormProtector': 1,
#   'basement': 3659,
#   'attic': 3569,
#   'garage': 923,
#   'hasStorageRoom': 0,
#   'hasGuestRoom': 5,
#   'price': 1829876.4,
#   'category': 'Basic',
#   'id': 'fbd9f77e-30cb-4514-802f-17a0c5e8aa10',
#   'prediction': 1830830},
#  {'_id': ObjectId('62fce29254763af87827f7dc'),
#   'index': 8029,
#   'squareMeters': 73112,
#   'numberOfRooms': 24,
#   'hasYard': 1,
#   'hasPool': 1,
#   'floors': 60,
#   'cityCode': 7935,
#   'cityPartRange': 8,
#   'numPrevOwners': 8,
#   'made': 2014,
#   'isNewBuilt': 0,
#   'hasStormProtector': 0,
#   'basement': 3662,
#   'attic': 3711,
#   'garage': 811,
#   'hasStorageRoom': 0,
#   'hasGuestRoom': 8,
#   'price': 7325772.4,
#   'category': 'Basic',
#   'id': '9bfa742e-5da9-4e4f-a2d3-9d68d1e4eb8a',
#   'prediction': 7317707},
#  {'_id': ObjectId('62fce29354763af87827f7dd'),
#   'index': 9151,
#   'squareMeters': 85429,
#   'numberOfRooms': 20,
#   'hasYard': 0,
#   'hasPool': 0,
#   'floors': 28,
#   'cityCode': 59987,
#   'cityPartRange': 7,
#   'numPrevOwners': 8,
#   'made': 2014,
#   'isNewBuilt': 1,
#   'hasStormProtector': 1,
#   'basement': 2582,
#   'attic': 330,
#   'garage': 918,
#   'hasStorageRoom': 0,
#   'hasGuestRoom': 3,
#   'price': 8546147.4,
#   'category': 'Basic',
#   'id': '8a2e8b80-5db9-42b3-b19e-160623bd0340',
#   'prediction': 8549424},
#  {'_id': ObjectId('62fce29454763af87827f7de'),
#   'index': 8974,
#   'squareMeters': 36690,
#   'numberOfRooms': 68,
#   'hasYard': 1,
#   'hasPool': 0,
#   'floors': 27,
#   'cityCode': 18808,
#   'cityPartRange': 9,
#   'numPrevOwners': 4,
#   'made': 2014,
#   'isNewBuilt': 1,
#   'hasStormProtector': 0,
#   'basement': 8571,
#   'attic': 187,
#   'garage': 598,
#   'hasStorageRoom': 0,
#   'hasGuestRoom': 0,
#   'price': 3674806.4,
#   'category': 'Basic',
#   'id': 'dac6bae9-44f0-408c-a288-6c3e101dc890',
#   'prediction': 3675456},
#  {'_id': ObjectId('62fce29554763af87827f7df'),
#   'index': 7926,
#   'squareMeters': 74234,
#   'numberOfRooms': 94,
#   'hasYard': 1,
#   'hasPool': 0,
#   'floors': 20,
#   'cityCode': 14556,
#   'cityPartRange': 2,
#   'numPrevOwners': 5,
#   'made': 2014,
#   'isNewBuilt': 0,
#   'hasStormProtector': 1,
#   'basement': 9576,
#   'attic': 1323,
#   'garage': 734,
#   'hasStorageRoom': 1,
#   'hasGuestRoom': 5,
#   'price': 7426071.4,
#   'category': 'Basic',
#   'id': '39da793a-67f4-43a9-b37a-4b0220e45809',
#   'prediction': 7429908},
#  {'_id': ObjectId('62fce29654763af87827f7e0'),
#   'index': 1545,
#   'squareMeters': 5577,
#   'numberOfRooms': 44,
#   'hasYard': 0,
#   'hasPool': 0,
#   'floors': 79,
#   'cityCode': 36379,
#   'cityPartRange': 7,
#   'numPrevOwners': 5,
#   'made': 2014,
#   'isNewBuilt': 0,
#   'hasStormProtector': 0,
#   'basement': 8539,
#   'attic': 1227,
#   'garage': 747,
#   'hasStorageRoom': 1,
#   'hasGuestRoom': 5,
#   'price': 565361.4,
#   'category': 'Basic',
#   'id': '4cccd3f7-42b0-4cc2-97da-dffeef1c65e7',
#   'prediction': 564112},
#  {'_id': ObjectId('62fce29754763af87827f7e1'),
#   'index': 556,
#   'squareMeters': 13414,
#   'numberOfRooms': 59,
#   'hasYard': 1,
#   'hasPool': 1,
#   'floors': 16,
#   'cityCode': 81829,
#   'cityPartRange': 4,
#   'numPrevOwners': 6,
#   'made': 2014,
#   'isNewBuilt': 1,
#   'hasStormProtector': 1,
#   'basement': 6223,
#   'attic': 571,
#   'garage': 477,
#   'hasStorageRoom': 0,
#   'hasGuestRoom': 5,
#   'price': 1350225.4,
#   'category': 'Luxury',
#   'id': '03f7a649-79e0-430f-991f-fe8c0d3e3692',
#   'prediction': 1347823},
#  {'_id': ObjectId('62fce29854763af87827f7e2'),
#   'index': 7920,
#   'squareMeters': 9940,
#   'numberOfRooms': 2,
#   'hasYard': 1,
#   'hasPool': 1,
#   'floors': 66,
#   'cityCode': 4659,
#   'cityPartRange': 7,
#   'numPrevOwners': 4,
#   'made': 2014,
#   'isNewBuilt': 0,
#   'hasStormProtector': 1,
#   'basement': 5152,
#   'attic': 876,
#   'garage': 205,
#   'hasStorageRoom': 0,
#   'hasGuestRoom': 6,
#   'price': 1003072.4,
#   'category': 'Basic',
#   'id': '871d8ac4-ab47-4ef2-8b82-723caf68dc6d',
#   'prediction': 1000418},
#  {'_id': ObjectId('62fce29954763af87827f7e3'),
#   'index': 7919,
#   'squareMeters': 27226,
#   'numberOfRooms': 80,
#   'hasYard': 0,
#   'hasPool': 0,
#   'floors': 77,
#   'cityCode': 30704,
#   'cityPartRange': 10,
#   'numPrevOwners': 2,
#   'made': 2014,
#   'isNewBuilt': 0,
#   'hasStormProtector': 1,
#   'basement': 2978,
#   'attic': 4685,
#   'garage': 775,
#   'hasStorageRoom': 1,
#   'hasGuestRoom': 10,
#   'price': 2726812.4,
#   'category': 'Basic',
#   'id': 'e0e7c6de-53c2-4657-8c46-310684d3c8cc',
#   'prediction': 2729043},
#  {'_id': ObjectId('62fce29a54763af87827f7e4'),
#   'index': 9479,
#   'squareMeters': 65531,
#   'numberOfRooms': 36,
#   'hasYard': 1,
#   'hasPool': 1,
#   'floors': 35,
#   'cityCode': 57641,
#   'cityPartRange': 7,
#   'numPrevOwners': 10,
#   'made': 2014,
#   'isNewBuilt': 1,
#   'hasStormProtector': 1,
#   'basement': 4998,
#   'attic': 5786,
#   'garage': 603,
#   'hasStorageRoom': 0,
#   'hasGuestRoom': 8,
#   'price': 6565552.4,
#   'category': 'Luxury',
#   'id': 'e7811644-11b0-4fc2-b31f-64d682a500ce',
#   'prediction': 6559596},
#  {'_id': ObjectId('62fce29b54763af87827f7e5'),
#   'index': 965,
#   'squareMeters': 94293,
#   'numberOfRooms': 2,
#   'hasYard': 1,
#   'hasPool': 0,
#   'floors': 63,
#   'cityCode': 75139,
#   'cityPartRange': 6,
#   'numPrevOwners': 5,
#   'made': 2014,
#   'isNewBuilt': 1,
#   'hasStormProtector': 1,
#   'basement': 7991,
#   'attic': 9703,
#   'garage': 190,
#   'hasStorageRoom': 0,
#   'hasGuestRoom': 3,
#   'price': 9434658.4,
#   'category': 'Basic',
#   'id': 'c0ea94bd-f4db-4407-ad10-852cc1f9bded',
#   'prediction': 9435836},
#  {'_id': ObjectId('62fce29c54763af87827f7e6'),
#   'index': 7930,
#   'squareMeters': 7608,
#   'numberOfRooms': 54,
#   'hasYard': 0,
#   'hasPool': 0,
#   'floors': 99,
#   'cityCode': 42542,
#   'cityPartRange': 2,
#   'numPrevOwners': 7,
#   'made': 2014,
#   'isNewBuilt': 1,
#   'hasStormProtector': 1,
#   'basement': 937,
#   'attic': 2352,
#   'garage': 717,
#   'hasStorageRoom': 0,
#   'hasGuestRoom': 0,
#   'price': 768431.4,
#   'category': 'Basic',
#   'id': '336047d8-7a69-41d7-9367-ddddd37062a8',
#   'prediction': 767215},
#  {'_id': ObjectId('62fce29d54763af87827f7e7'),
#   'index': 8508,
#   'squareMeters': 10250,
#   'numberOfRooms': 7,
#   'hasYard': 0,
#   'hasPool': 0,
#   'floors': 1,
#   'cityCode': 98896,
#   'cityPartRange': 7,
#   'numPrevOwners': 8,
#   'made': 2014,
#   'isNewBuilt': 0,
#   'hasStormProtector': 1,
#   'basement': 9105,
#   'attic': 6518,
#   'garage': 259,
#   'hasStorageRoom': 1,
#   'hasGuestRoom': 0,
#   'price': 1025802.4,
#   'category': 'Basic',
#   'id': 'e4ef19a5-71ee-4e51-923e-ded83b6383e0',
#   'prediction': 1031419},
#  {'_id': ObjectId('62fce29e54763af87827f7e8'),
#   'index': 4741,
#   'squareMeters': 25124,
#   'numberOfRooms': 97,
#   'hasYard': 0,
#   'hasPool': 1,
#   'floors': 25,
#   'cityCode': 83534,
#   'cityPartRange': 6,
#   'numPrevOwners': 9,
#   'made': 2014,
#   'isNewBuilt': 0,
#   'hasStormProtector': 1,
#   'basement': 397,
#   'attic': 8988,
#   'garage': 962,
#   'hasStorageRoom': 0,
#   'hasGuestRoom': 3,
#   'price': 2517156.4,
#   'category': 'Basic',
#   'id': 'e8b82ba0-3ab1-49df-918a-cbf78f9fa453',
#   'prediction': 2518840},
#  {'_id': ObjectId('62fce29f54763af87827f7e9'),
#   'index': 680,
#   'squareMeters': 79093,
#   'numberOfRooms': 89,
#   'hasYard': 1,
#   'hasPool': 1,
#   'floors': 63,
#   'cityCode': 31911,
#   'cityPartRange': 9,
#   'numPrevOwners': 9,
#   'made': 2014,
# ...
#   'numberOfRooms': 97,
#   'hasYard': 0,
#   'hasPool': 1,
#   'floors': 85,
#   'cityCode': 81543,
#   'cityPartRange': 9,
#   'numPrevOwners': 6,
#   'made': 2015,
#   'isNewBuilt': 1,
#   'hasStormProtector': 1,
#   'basement': 5075,
#   'attic': 5017,
#   'garage': 936,
#   'hasStorageRoom': 1,
#   'hasGuestRoom': 1,
#   'price': 6084063.5,
#   'category': 'Basic',
#   'id': '0eca79c3-cb2e-4075-b2a3-eaafa714d211',
#   'prediction': 6080989},
#  {'_id': ObjectId('62fce44b54763af87827f987'),
#   'index': 465,
#   'squareMeters': 80988,
#   'numberOfRooms': 34,
#   'hasYard': 0,
#   'hasPool': 1,
#   'floors': 57,
#   'cityCode': 56385,
#   'cityPartRange': 6,
#   'numPrevOwners': 10,
#   'made': 2015,
#   'isNewBuilt': 0,
#   'hasStormProtector': 1,
#   'basement': 8135,
#   'attic': 7450,
#   'garage': 321,
#   'hasStorageRoom': 1,
#   'hasGuestRoom': 10,
#   'price': 8104253.5,
#   'category': 'Basic',
#   'id': 'd72db71b-b0ac-412c-b36d-da276dccc0a7',
#   'prediction': 8105317},
#  {'_id': ObjectId('62fce44c54763af87827f988'),
#   'index': 1206,
#   'squareMeters': 44913,
#   'numberOfRooms': 30,
#   'hasYard': 0,
#   'hasPool': 0,
#   'floors': 39,
#   'cityCode': 33937,
#   'cityPartRange': 9,
#   'numPrevOwners': 9,
#   'made': 2015,
#   'isNewBuilt': 0,
#   'hasStormProtector': 0,
#   'basement': 6521,
#   'attic': 3690,
#   'garage': 652,
#   'hasStorageRoom': 1,
#   'hasGuestRoom': 10,
#   'price': 4493550.5,
#   'category': 'Basic',
#   'id': '20d415cb-e513-4fe4-99dc-9ea0af6ebaf7',
#   'prediction': 4497767},
#  {'_id': ObjectId('62fce44d54763af87827f989'),
#   'index': 9755,
#   'squareMeters': 27803,
#   'numberOfRooms': 63,
#   'hasYard': 1,
#   'hasPool': 1,
#   'floors': 13,
#   'cityCode': 82477,
#   'cityPartRange': 5,
#   'numPrevOwners': 3,
#   'made': 2015,
#   'isNewBuilt': 0,
#   'hasStormProtector': 0,
#   'basement': 1307,
#   'attic': 1354,
#   'garage': 754,
#   'hasStorageRoom': 0,
#   'hasGuestRoom': 1,
#   'price': 2788829.5,
#   'category': 'Basic',
#   'id': 'f24c8f18-a8f2-4ad0-b5c2-bc81f87646bd',
#   'prediction': 2786743},
#  {'_id': ObjectId('62fce44e54763af87827f98a'),
#   'index': 2990,
#   'squareMeters': 81892,
#   'numberOfRooms': 7,
#   'hasYard': 1,
#   'hasPool': 1,
#   'floors': 69,
#   'cityCode': 29384,
#   'cityPartRange': 3,
#   'numPrevOwners': 10,
#   'made': 2015,
#   'isNewBuilt': 0,
#   'hasStormProtector': 0,
#   'basement': 9180,
#   'attic': 2785,
#   'garage': 230,
#   'hasStorageRoom': 1,
#   'hasGuestRoom': 6,
#   'price': 8204629.5,
#   'category': 'Basic',
#   'id': '92b0a2e8-7d2d-4d2a-8633-6d24f7c591cb',
#   'prediction': 8195719},
#  {'_id': ObjectId('62fce44f54763af87827f98b'),
#   'index': 4639,
#   'squareMeters': 30821,
#   'numberOfRooms': 52,
#   'hasYard': 0,
#   'hasPool': 1,
#   'floors': 27,
#   'cityCode': 82221,
#   'cityPartRange': 8,
#   'numPrevOwners': 10,
#   'made': 2015,
#   'isNewBuilt': 0,
#   'hasStormProtector': 0,
#   'basement': 5620,
#   'attic': 4492,
#   'garage': 408,
#   'hasStorageRoom': 0,
#   'hasGuestRoom': 10,
#   'price': 3086776.5,
#   'category': 'Basic',
#   'id': '58514ece-ac61-41b2-952f-3fda453838a3',
#   'prediction': 3088548},
#  {'_id': ObjectId('62fce45054763af87827f98c'),
#   'index': 3935,
#   'squareMeters': 23513,
#   'numberOfRooms': 11,
#   'hasYard': 0,
#   'hasPool': 1,
#   'floors': 26,
#   'cityCode': 65711,
#   'cityPartRange': 9,
#   'numPrevOwners': 5,
#   'made': 2015,
#   'isNewBuilt': 0,
#   'hasStormProtector': 1,
#   'basement': 1411,
#   'attic': 1522,
#   'garage': 880,
#   'hasStorageRoom': 0,
#   'hasGuestRoom': 10,
#   'price': 2357581.5,
#   'category': 'Basic',
#   'id': '7942d66b-685b-4ad8-bea6-cd4b63608f33',
#   'prediction': 2357737},
#  {'_id': ObjectId('62fce45154763af87827f98d'),
#   'index': 1876,
#   'squareMeters': 50793,
#   'numberOfRooms': 51,
#   'hasYard': 0,
#   'hasPool': 1,
#   'floors': 21,
#   'cityCode': 57949,
#   'cityPartRange': 4,
#   'numPrevOwners': 9,
#   'made': 2015,
#   'isNewBuilt': 0,
#   'hasStormProtector': 0,
#   'basement': 4263,
#   'attic': 8736,
#   'garage': 860,
#   'hasStorageRoom': 1,
#   'hasGuestRoom': 10,
#   'price': 5082950.5,
#   'category': 'Basic',
#   'id': '49f34472-1fde-4797-aae3-f64b09a55049',
#   'prediction': 5085775},
#  {'_id': ObjectId('62fce45254763af87827f98e'),
#   'index': 7614,
#   'squareMeters': 40124,
#   'numberOfRooms': 40,
#   'hasYard': 1,
#   'hasPool': 1,
#   'floors': 8,
#   'cityCode': 15680,
#   'cityPartRange': 2,
#   'numPrevOwners': 1,
#   'made': 2015,
#   'isNewBuilt': 1,
#   'hasStormProtector': 1,
#   'basement': 5020,
#   'attic': 5098,
#   'garage': 256,
#   'hasStorageRoom': 1,
#   'hasGuestRoom': 4,
#   'price': 4020581.5,
#   'category': 'Luxury',
#   'id': 'cf4e4371-64f9-40f7-9b26-1b30a4996415',
#   'prediction': 4018861},
#  {'_id': ObjectId('62fce45354763af87827f98f'),
#   'index': 5808,
#   'squareMeters': 85185,
#   'numberOfRooms': 23,
#   'hasYard': 0,
#   'hasPool': 1,
#   'floors': 11,
#   'cityCode': 95024,
#   'cityPartRange': 1,
#   'numPrevOwners': 1,
#   'made': 2015,
#   'isNewBuilt': 0,
#   'hasStormProtector': 0,
#   'basement': 9938,
#   'attic': 6650,
#   'garage': 370,
#   'hasStorageRoom': 0,
#   'hasGuestRoom': 2,
#   'price': 8522775.5,
#   'category': 'Basic',
#   'id': '6e2a55fe-fdb4-4249-bb7d-b19b664d4ffe',
#   'prediction': 8525023},
#  {'_id': ObjectId('62fce45454763af87827f990'),
#   'index': 1879,
#   'squareMeters': 41987,
#   'numberOfRooms': 94,
#   'hasYard': 0,
#   'hasPool': 1,
#   'floors': 26,
#   'cityCode': 13554,
#   'cityPartRange': 6,
#   'numPrevOwners': 1,
#   'made': 2015,
#   'isNewBuilt': 1,
#   'hasStormProtector': 0,
#   'basement': 6361,
#   'attic': 935,
#   'garage': 283,
#   'hasStorageRoom': 0,
#   'hasGuestRoom': 6,
#   'price': 4203907.5,
#   'category': 'Basic',
#   'id': '520bd68b-9ade-465e-a715-45efcf401e9e',
#   'prediction': 4205163},
#  {'_id': ObjectId('62fce45554763af87827f991'),
#   'index': 9680,
#   'squareMeters': 62751,
#   'numberOfRooms': 59,
#   'hasYard': 0,
#   'hasPool': 1,
#   'floors': 92,
#   'cityCode': 91718,
#   'cityPartRange': 4,
#   'numPrevOwners': 4,
#   'made': 2015,
#   'isNewBuilt': 0,
#   'hasStormProtector': 0,
#   'basement': 6432,
#   'attic': 1214,
#   'garage': 959,
#   'hasStorageRoom': 0,
#   'hasGuestRoom': 7,
#   'price': 6284421.5,
#   'category': 'Basic',
#   'id': '2f89eed2-2c4e-4156-8fc9-220dc5a8856c',
#   'prediction': 6281592},
#  {'_id': ObjectId('62fce45654763af87827f992'),
#   'index': 8728,
#   'squareMeters': 41050,
#   'numberOfRooms': 6,
#   'hasYard': 0,
#   'hasPool': 1,
#   'floors': 87,
#   'cityCode': 10831,
#   'cityPartRange': 2,
#   'numPrevOwners': 1,
#   'made': 2015,
#   'isNewBuilt': 0,
#   'hasStormProtector': 1,
#   'basement': 4162,
#   'attic': 1768,
#   'garage': 756,
#   'hasStorageRoom': 0,
#   'hasGuestRoom': 6,
#   'price': 4117975.5,
#   'category': 'Basic',
#   'id': 'b505203f-221d-4f6c-8abc-9f568761d2da',
#   'prediction': 4111462},
#  {'_id': ObjectId('62fce45754763af87827f993'),
#   'index': 3843,
#   'squareMeters': 50327,
#   'numberOfRooms': 82,
#   'hasYard': 0,
#   'hasPool': 1,
#   'floors': 8,
#   'cityCode': 43787,
#   'cityPartRange': 10,
#   'numPrevOwners': 10,
#   'made': 2015,
#   'isNewBuilt': 0,
#   'hasStormProtector': 0,
#   'basement': 334,
#   'attic': 5441,
#   'garage': 981,
#   'hasStorageRoom': 1,
#   'hasGuestRoom': 3,
#   'price': 5036872.5,
#   'category': 'Basic',
#   'id': 'eb12a106-ac59-45a1-bf82-fb77ec043479',
#   'prediction': 5039175},
#  {'_id': ObjectId('62fce45854763af87827f994'),
#   'index': 7902,
#   'squareMeters': 24136,
#   'numberOfRooms': 47,
#   'hasYard': 0,
#   'hasPool': 0,
#   'floors': 50,
#   'cityCode': 40216,
#   'cityPartRange': 6,
#   'numPrevOwners': 6,
#   'made': 2015,
#   'isNewBuilt': 0,
#   'hasStormProtector': 0,
#   'basement': 9862,
#   'attic': 8547,
#   'garage': 487,
#   'hasStorageRoom': 1,
#   'hasGuestRoom': 0,
#   'price': 2415551.5,
#   'category': 'Basic',
#   'id': '2015183f-e151-4cf2-b473-2b29aeba6024',
#   'prediction': 2420038},
#  {'_id': ObjectId('62fce45954763af87827f995'),
#   'index': 1881,
#   'squareMeters': 55434,
#   'numberOfRooms': 55,
#   'hasYard': 1,
#   'hasPool': 0,
#   'floors': 97,
#   'cityCode': 98846,
#   'cityPartRange': 7,
#   'numPrevOwners': 9,
#   'made': 2015,
#   'isNewBuilt': 1,
#   'hasStormProtector': 0,
#   'basement': 9485,
#   'attic': 3863,
#   'garage': 774,
#   'hasStorageRoom': 0,
#   'hasGuestRoom': 9,
#   'price': 5547739.5,
#   'category': 'Basic',
#   'id': '2cc88c78-2d0c-4a1c-832d-81432ae03d36',
#   'prediction': 5549882},
#  {'_id': ObjectId('62fce45a54763af87827f996'),
#   'index': 686,
#   'squareMeters': 70367,
#   'numberOfRooms': 63,
#   'hasYard': 1,
#   'hasPool': 0,
#   'floors': 19,
#   'cityCode': 82251,
#   'cityPartRange': 8,
#   'numPrevOwners': 1,
#   'made': 2015,
#   'isNewBuilt': 0,
#   'hasStormProtector': 1,
#   'basement': 8131,
#   'attic': 2786,
#   'garage': 635,
#   'hasStorageRoom': 1,
#   'hasGuestRoom': 0,
#   'price': 7043100.5,
#   'category': 'Basic',
#   'id': '18b5a5b2-90c6-43db-83e8-cbd7edc42e5e',
#   'prediction': 7043203},
#  {'_id': ObjectId('62fce45b54763af87827f997'),
#   'index': 6766,
#   'squareMeters': 83281,
#   'numberOfRooms': 55,
#   'hasYard': 1,
#   'hasPool': 0,
#   'floors': 2,
#   'cityCode': 63544,
#   'cityPartRange': 8,
#   'numPrevOwners': 7,
#   'made': 2015,
#   'isNewBuilt': 0,
#   'hasStormProtector': 1,
#   'basement': 245,
#   'attic': 5013,
#   'garage': 152,
#   'hasStorageRoom': 0,
#   'hasGuestRoom': 6,
#   'price': 8332688.5,
#   'category': 'Basic',
#   'id': 'c11b39f3-00e1-4534-b8af-cfc428bd801a',
#   'prediction': 8334621},
#  {'_id': ObjectId('62fce45c54763af87827f998'),
#   'index': 9679,
#   'squareMeters': 13659,
#   'numberOfRooms': 10,
#   'hasYard': 0,
#   'hasPool': 1,
#   'floors': 100,
#   'cityCode': 33818,
#   'cityPartRange': 9,
#   'numPrevOwners': 9,
#   'made': 2015,
#   'isNewBuilt': 1,
#   'hasStormProtector': 0,
#   'basement': 5179,
#   'attic': 4586,
#   'garage': 793,
#   'hasStorageRoom': 0,
#   'hasGuestRoom': 3,
#   'price': 1373742.5,
#   'category': 'Basic',
#   'id': 'b4860fbb-e689-4c0a-bbf9-1d60d27003e6',
#   'prediction': 1372324},
#  {'_id': ObjectId('62fce45d54763af87827f999'),
#   'index': 9693,
#   'squareMeters': 94081,
#   'numberOfRooms': 47,
#   'hasYard': 0,
#   'hasPool': 1,
#   'floors': 75,
#   'cityCode': 68146,
#   'cityPartRange': 4,
#   'numPrevOwners': 5,
#   'made': 2015,
#   'isNewBuilt': 0,
#   'hasStormProtector': 0,
#   'basement': 3111,
#   'attic': 6604,
#   'garage': 912,
#   'hasStorageRoom': 0,
#   'hasGuestRoom': 6,
#   'price': 9411954.5,
#   'category': 'Basic',
#   'id': '2b788395-b303-467c-9cea-af826545b1d5',
#   'prediction': 9414636},
#  {'_id': ObjectId('62fce45e54763af87827f99a'),
#   'index': 3644,
#   'squareMeters': 26506,
#   'numberOfRooms': 95,
#   'hasYard': 0,
#   'hasPool': 1,
#   'floors': 69,
#   'cityCode': 86093,
#   'cityPartRange': 4,
#   'numPrevOwners': 3,
#   'made': 2015,
#   'isNewBuilt': 1,
#   'hasStormProtector': 0,
#   'basement': 9373,
#   'attic': 6376,
#   'garage': 509,
#   'hasStorageRoom': 0,
#   'hasGuestRoom': 1,
#   'price': 2660579.5,
#   'category': 'Basic',
#   'id': '247545ff-08b5-40ef-9221-65ca2b38036a',
#   'prediction': 2657042},
#  {'_id': ObjectId('62fce45f54763af87827f99b'),
#   'index': 6619,
#   'squareMeters': 42557,
#   'numberOfRooms': 71,
#   'hasYard': 1,
#   'hasPool': 1,
#   'floors': 23,
#   'cityCode': 46686,
#   'cityPartRange': 9,
#   'numPrevOwners': 2,
#   'made': 2015,
#   'isNewBuilt': 1,
#   'hasStormProtector': 1,
#   'basement': 880,
#   'attic': 1526,
#   'garage': 938,
#   'hasStorageRoom': 1,
#   'hasGuestRoom': 7,
#   'price': 4264085.5,
#   'category': 'Luxury',
#   'id': '7edd075b-6604-4f05-9856-929b42cd7306',
#   'prediction': 4262164},
#  {'_id': ObjectId('62fce46154763af87827f99c'),
#   'index': 6248,
#   'squareMeters': 45179,
#   'numberOfRooms': 14,
#   'hasYard': 0,
#   'hasPool': 0,
#   'floors': 10,
#   'cityCode': 58110,
#   'cityPartRange': 8,
#   'numPrevOwners': 8,
#   'made': 2015,
#   'isNewBuilt': 0,
#   'hasStormProtector': 0,
#   'basement': 6509,
#   'attic': 4737,
#   'garage': 559,
#   'hasStorageRoom': 1,
#   'hasGuestRoom': 7,
#   'price': 4519301.5,
#   'category': 'Basic',
#   'id': '94010b75-dc5d-488c-a586-ac7aa8b80190',
#   'prediction': 4524368},
#  {'_id': ObjectId('62fce46254763af87827f99d'),
#   'index': 5842,
#   'squareMeters': 44593,
#   'numberOfRooms': 83,
#   'hasYard': 0,
#   'hasPool': 1,
#   'floors': 21,
#   'cityCode': 45854,
#   'cityPartRange': 8,
#   'numPrevOwners': 10,
#   'made': 2015,
#   'isNewBuilt': 1,
#   'hasStormProtector': 1,
#   'basement': 320,
#   'attic': 7934,
#   'garage': 470,
#   'hasStorageRoom': 1,
#   'hasGuestRoom': 3,
#   'price': 4465177.5,
#   'category': 'Basic',
#   'id': 'a61cb16c-193b-423f-8df5-8c577fbc317c',
#   'prediction': 4465767},
#  {'_id': ObjectId('62fce46354763af87827f99e'),
#   'index': 292,
#   'squareMeters': 2523,
#   'numberOfRooms': 12,
#   'hasYard': 1,
#   'hasPool': 1,
#   'floors': 67,
#   'cityCode': 75753,
#   'cityPartRange': 3,
#   'numPrevOwners': 10,
#   'made': 2015,
#   'isNewBuilt': 1,
#   'hasStormProtector': 1,
#   'basement': 150,
#   'attic': 473,
#   'garage': 949,
#   'hasStorageRoom': 1,
#   'hasGuestRoom': 1,
#   'price': 260710.5,
#   'category': 'Luxury',
#   'id': '7611b08f-962c-497e-91fd-ef9813339fd6',
#   'prediction': 258708},
#  {'_id': ObjectId('62fce46454763af87827f99f'),
#   'index': 9983,
#   'squareMeters': 87627,
#   'numberOfRooms': 56,
#   'hasYard': 1,
#   'hasPool': 0,
#   'floors': 95,
#   'cityCode': 33850,
#   'cityPartRange': 9,
#   'numPrevOwners': 9,
#   'made': 2015,
#   'isNewBuilt': 1,
#   'hasStormProtector': 0,
#   'basement': 2522,
#   'attic': 988,
#   'garage': 735,
#   'hasStorageRoom': 0,
#   'hasGuestRoom': 9,
#   'price': 8766795.5,
#   'category': 'Basic',
#   'id': '3a0e6187-ffa5-4762-873c-501d0ae28800',
#   'prediction': 8769227},
#  {'_id': ObjectId('62fce46554763af87827f9a0'),
#   'index': 5564,
#   'squareMeters': 93443,
#   'numberOfRooms': 16,
#   'hasYard': 1,
#   'hasPool': 0,
#   'floors': 93,
#   'cityCode': 74734,
#   'cityPartRange': 9,
#   'numPrevOwners': 3,
#   'made': 2015,
#   'isNewBuilt': 0,
#   'hasStormProtector': 1,
#   'basement': 9796,
#   'attic': 3588,
#   'garage': 139,
#   'hasStorageRoom': 0,
#   'hasGuestRoom': 5,
#   'price': 9349955.5,
#   'category': 'Basic',
#   'id': '56ca7b3e-af8d-4db8-b2d6-f0a135dbcf83',
#   'prediction': 9350835},
#  {'_id': ObjectId('62fce46654763af87827f9a1'),
#   'index': 5069,
#   'squareMeters': 85101,
#   'numberOfRooms': 91,
#   'hasYard': 1,
#   'hasPool': 1,
#   'floors': 44,
#   'cityCode': 33026,
#   'cityPartRange': 2,
#   'numPrevOwners': 3,
#   'made': 2015,
#   'isNewBuilt': 0,
#   'hasStormProtector': 0,
#   'basement': 908,
#   'attic': 9450,
#   'garage': 104,
#   'hasStorageRoom': 1,
#   'hasGuestRoom': 10,
#   'price': 8517678.5,
#   'category': 'Basic',
#   'id': 'c51882ce-f082-4308-bb4d-735217e84f46',
#   'prediction': 8516623},
#  {'_id': ObjectId('62fce46754763af87827f9a2'),
#   'index': 8763,
#   'squareMeters': 82952,
#   'numberOfRooms': 31,
#   'hasYard': 1,
#   'hasPool': 0,
#   'floors': 7,
#   'cityCode': 95942,
#   'cityPartRange': 9,
#   'numPrevOwners': 3,
#   'made': 2015,
#   'isNewBuilt': 1,
#   'hasStormProtector': 1,
#   'basement': 9960,
#   'attic': 9188,
#   'garage': 606,
#   'hasStorageRoom': 0,
#   'hasGuestRoom': 0,
#   'price': 8299689.5,
#   'category': 'Basic',
#   'id': '0270e3b4-d9db-44dc-828f-bb30c8128a3c',
#   'prediction': 8301720},
#  {'_id': ObjectId('62fce46854763af87827f9a3'),
#   'index': 1163,
#   'squareMeters': 1887,
#   'numberOfRooms': 70,
#   'hasYard': 0,
#   'hasPool': 1,
#   'floors': 28,
#   'cityCode': 91863,
#   'cityPartRange': 10,
#   'numPrevOwners': 9,
#   'made': 2015,
#   'isNewBuilt': 0,
#   'hasStormProtector': 0,
#   'basement': 3200,
#   'attic': 4500,
#   'garage': 594,
#   'hasStorageRoom': 0,
#   'hasGuestRoom': 6,
#   'price': 194035.5,
#   'category': 'Basic',
#   'id': '0f88b5e2-2a31-4942-a0d2-67a7473774fc',
#   'prediction': 195107},
#  {'_id': ObjectId('62fce46954763af87827f9a4'),
#   'index': 3918,
#   'squareMeters': 67226,
#   'numberOfRooms': 25,
#   'hasYard': 1,
#   'hasPool': 0,
#   'floors': 73,
#   'cityCode': 49694,
#   'cityPartRange': 7,
#   'numPrevOwners': 9,
#   'made': 2015,
#   'isNewBuilt': 0,
#   'hasStormProtector': 0,
#   'basement': 3250,
#   'attic': 8704,
#   'garage': 826,
#   'hasStorageRoom': 0,
#   'hasGuestRoom': 8,
#   'price': 6733312.5,
#   'category': 'Basic',
#   'id': 'f47a95ce-a58c-4e34-808e-3fd2057c24b3',
#   'prediction': 6729098},
#  {'_id': ObjectId('62fce46a54763af87827f9a5'),
#   'index': 3575,
#   'squareMeters': 8731,
#   'numberOfRooms': 90,
#   'hasYard': 1,
#   'hasPool': 1,
#   'floors': 24,
#   'cityCode': 3317,
#   'cityPartRange': 8,
#   'numPrevOwners': 10,
#   'made': 2015,
#   'isNewBuilt': 1,
#   'hasStormProtector': 1,
#   'basement': 8290,
#   'attic': 7290,
#   'garage': 777,
#   'hasStorageRoom': 0,
#   'hasGuestRoom': 3,
#   'price': 880713.5,
#   'category': 'Luxury',
#   'id': '3737b2ec-6b2b-48b1-8bd0-4eae370ba254',
#   'prediction': 879517}]

# %%
list(data[0])
# Out:
# ['_id',
#  'index',
#  'squareMeters',
#  'numberOfRooms',
#  'hasYard',
#  'hasPool',
#  'floors',
#  'cityCode',
#  'cityPartRange',
#  'numPrevOwners',
#  'made',
#  'isNewBuilt',
#  'hasStormProtector',
#  'basement',
#  'attic',
#  'garage',
#  'hasStorageRoom',
#  'hasGuestRoom',
#  'price',
#  'category',
#  'id',
#  'prediction']

# %%
len(data)
# Out:
# 540

# %%
#get collection 
report_collection = db.get_collection("report")
reports = list(report_collection.find())

# %%
reports[0]
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-77-2a278fac4d5e> in <module>
# ----> 1 reports[0]
#
# IndexError: list index out of range
